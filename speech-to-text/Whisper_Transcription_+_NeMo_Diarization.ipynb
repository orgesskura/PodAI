# %% [markdown]
# # Installing Dependencies

# %%
# !pip install git+https://github.com/m-bain/whisperX.git@78dcfaab51005aa703ee21375f81ed31bc248560
# !pip install --no-build-isolation nemo_toolkit[asr]==1.23.0
# !pip install --no-deps git+https://github.com/facebookresearch/demucs#egg=demucs
# !pip install git+https://github.com/oliverguhr/deepmultilingualpunctuation.git
# !pip install git+https://github.com/MahmoudAshraf97/ctc-forced-aligner.git
# Out:
# Collecting git+https://github.com/m-bain/whisperX.git@78dcfaab51005aa703ee21375f81ed31bc248560
#   Cloning https://github.com/m-bain/whisperX.git (to revision 78dcfaab51005aa703ee21375f81ed31bc248560) to /tmp/pip-req-build-an1ikt5v
#   Running command git clone --filter=blob:none --quiet https://github.com/m-bain/whisperX.git /tmp/pip-req-build-an1ikt5v
#   Running command git rev-parse -q --verify 'sha^78dcfaab51005aa703ee21375f81ed31bc248560'
#   Running command git fetch -q https://github.com/m-bain/whisperX.git 78dcfaab51005aa703ee21375f81ed31bc248560
#   Running command git checkout -q 78dcfaab51005aa703ee21375f81ed31bc248560
#   Resolved https://github.com/m-bain/whisperX.git to commit 78dcfaab51005aa703ee21375f81ed31bc248560
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=2 in /usr/local/lib/python3.10/dist-packages (from whisperx==3.1.1) (2.3.1+cu121)
# Requirement already satisfied: torchaudio>=2 in /usr/local/lib/python3.10/dist-packages (from whisperx==3.1.1) (2.3.1+cu121)
# Requirement already satisfied: faster-whisper==1.0.0 in /usr/local/lib/python3.10/dist-packages (from whisperx==3.1.1) (1.0.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from whisperx==3.1.1) (4.39.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from whisperx==3.1.1) (2.1.4)
# Requirement already satisfied: setuptools>=65 in /usr/local/lib/python3.10/dist-packages (from whisperx==3.1.1) (71.0.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from whisperx==3.1.1) (3.8.1)
# Requirement already satisfied: pyannote.audio==3.1.1 in /usr/local/lib/python3.10/dist-packages (from whisperx==3.1.1) (3.1.1)
# Requirement already satisfied: av==11.* in /usr/local/lib/python3.10/dist-packages (from faster-whisper==1.0.0->whisperx==3.1.1) (11.0.0)
# Requirement already satisfied: ctranslate2<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from faster-whisper==1.0.0->whisperx==3.1.1) (4.3.1)
# Requirement already satisfied: huggingface-hub>=0.13 in /usr/local/lib/python3.10/dist-packages (from faster-whisper==1.0.0->whisperx==3.1.1) (0.23.5)
# Requirement already satisfied: tokenizers<0.16,>=0.13 in /usr/local/lib/python3.10/dist-packages (from faster-whisper==1.0.0->whisperx==3.1.1) (0.15.2)
# Requirement already satisfied: onnxruntime<2,>=1.14 in /usr/local/lib/python3.10/dist-packages (from faster-whisper==1.0.0->whisperx==3.1.1) (1.19.0)
# Requirement already satisfied: asteroid-filterbanks>=0.4 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (0.4.0)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (0.8.0)
# Requirement already satisfied: lightning>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (2.4.0)
# Requirement already satisfied: omegaconf<3.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (2.3.0)
# Requirement already satisfied: pyannote.core>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (5.0.0)
# Requirement already satisfied: pyannote.database>=5.0.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (5.1.0)
# Requirement already satisfied: pyannote.metrics>=3.2 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (3.2.1)
# Requirement already satisfied: pyannote.pipeline>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (3.0.1)
# Requirement already satisfied: pytorch-metric-learning>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (2.6.0)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (13.7.1)
# Requirement already satisfied: semver>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (3.0.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (0.12.1)
# Requirement already satisfied: speechbrain>=0.5.14 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (1.0.0)
# Requirement already satisfied: tensorboardX>=2.6 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (2.6.2.2)
# Requirement already satisfied: torch-audiomentations>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (0.11.1)
# Requirement already satisfied: torchmetrics>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==3.1.1->whisperx==3.1.1) (1.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2->whisperx==3.1.1) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2->whisperx==3.1.1) (12.6.20)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->whisperx==3.1.1) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->whisperx==3.1.1) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->whisperx==3.1.1) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->whisperx==3.1.1) (4.66.5)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->whisperx==3.1.1) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->whisperx==3.1.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->whisperx==3.1.1) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->whisperx==3.1.1) (2024.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->whisperx==3.1.1) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->whisperx==3.1.1) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->whisperx==3.1.1) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->whisperx==3.1.1) (0.4.4)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (0.11.6)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.10/dist-packages (from lightning>=2.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (2.4.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf<3.0,>=2.1->pyannote.audio==3.1.1->whisperx==3.1.1) (4.9.3)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper==1.0.0->whisperx==3.1.1) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper==1.0.0->whisperx==3.1.1) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper==1.0.0->whisperx==3.1.1) (3.20.3)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from pyannote.core>=5.0.0->pyannote.audio==3.1.1->whisperx==3.1.1) (2.4.0)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.core>=5.0.0->pyannote.audio==3.1.1->whisperx==3.1.1) (1.13.1)
# Requirement already satisfied: typer>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.database>=5.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (0.12.3)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics>=3.2->pyannote.audio==3.1.1->whisperx==3.1.1) (1.3.2)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics>=3.2->pyannote.audio==3.1.1->whisperx==3.1.1) (0.6.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics>=3.2->pyannote.audio==3.1.1->whisperx==3.1.1) (0.9.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics>=3.2->pyannote.audio==3.1.1->whisperx==3.1.1) (3.7.1)
# Requirement already satisfied: optuna>=3.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.pipeline>=3.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (3.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->whisperx==3.1.1) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->pyannote.audio==3.1.1->whisperx==3.1.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->pyannote.audio==3.1.1->whisperx==3.1.1) (2.16.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->pyannote.audio==3.1.1->whisperx==3.1.1) (1.17.0)
# Requirement already satisfied: hyperpyyaml in /usr/local/lib/python3.10/dist-packages (from speechbrain>=0.5.14->pyannote.audio==3.1.1->whisperx==3.1.1) (1.2.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from speechbrain>=0.5.14->pyannote.audio==3.1.1->whisperx==3.1.1) (0.1.99)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2->whisperx==3.1.1) (1.3.0)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from torch-audiomentations>=0.11.0->pyannote.audio==3.1.1->whisperx==3.1.1) (0.2.7)
# Requirement already satisfied: librosa>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from torch-audiomentations>=0.11.0->pyannote.audio==3.1.1->whisperx==3.1.1) (0.10.2.post1)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from torch-audiomentations>=0.11.0->pyannote.audio==3.1.1->whisperx==3.1.1) (1.2.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2->whisperx==3.1.1) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->whisperx==3.1.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->whisperx==3.1.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->whisperx==3.1.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->whisperx==3.1.1) (2024.7.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->pyannote.audio==3.1.1->whisperx==3.1.1) (2.22)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (3.10.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio==3.1.1->whisperx==3.1.1) (3.0.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio==3.1.1->whisperx==3.1.1) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio==3.1.1->whisperx==3.1.1) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio==3.1.1->whisperx==3.1.1) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio==3.1.1->whisperx==3.1.1) (0.4.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio==3.1.1->whisperx==3.1.1) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio==3.1.1->whisperx==3.1.1) (1.0.8)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote.audio==3.1.1->whisperx==3.1.1) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio==3.1.1->whisperx==3.1.1) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio==3.1.1->whisperx==3.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio==3.1.1->whisperx==3.1.1) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio==3.1.1->whisperx==3.1.1) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio==3.1.1->whisperx==3.1.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio==3.1.1->whisperx==3.1.1) (3.1.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (1.13.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (6.8.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (2.0.32)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.17.1->pyannote.metrics>=3.2->pyannote.audio==3.1.1->whisperx==3.1.1) (3.5.0)
# Requirement already satisfied: primePy>=1.3 in /usr/local/lib/python3.10/dist-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.11.0->pyannote.audio==3.1.1->whisperx==3.1.1) (1.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (1.5.4)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper==1.0.0->whisperx==3.1.1) (10.0)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in /usr/local/lib/python3.10/dist-packages (from hyperpyyaml->speechbrain>=0.5.14->pyannote.audio==3.1.1->whisperx==3.1.1) (0.18.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (4.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (1.3.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio==3.1.1->whisperx==3.1.1) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote.audio==3.1.1->whisperx==3.1.1) (4.2.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain>=0.5.14->pyannote.audio==3.1.1->whisperx==3.1.1) (0.2.8)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio==3.1.1->whisperx==3.1.1) (3.0.3)
# Collecting nemo_toolkit==1.23.0 (from nemo_toolkit[asr]==1.23.0)
#   Using cached nemo_toolkit-1.23.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (0.23.5)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (0.60.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (1.26.4)
# Collecting onnx>=1.7.0 (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0)
#   Using cached onnx-1.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (2.8.2)
# Requirement already satisfied: ruamel.yaml in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (0.18.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (1.3.2)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (71.0.4)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (2.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (1.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (2.3.1+cu121)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (4.66.5)
# Requirement already satisfied: triton in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (2.3.1)
# Collecting wget (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0)
#   Using cached wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (1.16.0)
# Collecting braceexpand (from nemo_toolkit[asr]==1.23.0)
#   Using cached braceexpand-0.1.7-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (0.8.1)
# Collecting g2p-en (from nemo_toolkit[asr]==1.23.0)
#   Using cached g2p_en-2.1.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (7.7.1)
# Collecting jiwer (from nemo_toolkit[asr]==1.23.0)
#   Using cached jiwer-3.0.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting kaldi-python-io (from nemo_toolkit[asr]==1.23.0)
#   Using cached kaldi-python-io-1.2.2.tar.gz (8.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting kaldiio (from nemo_toolkit[asr]==1.23.0)
#   Using cached kaldiio-2.18.0-py3-none-any.whl.metadata (13 kB)
# Collecting lhotse>=1.20.0 (from nemo_toolkit[asr]==1.23.0)
#   Using cached lhotse-1.26.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: librosa>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (0.10.2.post1)
# Collecting marshmallow (from nemo_toolkit[asr]==1.23.0)
#   Using cached marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (3.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (24.1)
# Requirement already satisfied: pyannote.core in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (5.0.0)
# Requirement already satisfied: pyannote.metrics in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (3.2.1)
# Collecting pydub (from nemo_toolkit[asr]==1.23.0)
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting pyloudnorm (from nemo_toolkit[asr]==1.23.0)
#   Using cached pyloudnorm-0.1.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting resampy (from nemo_toolkit[asr]==1.23.0)
#   Using cached resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (1.13.1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (0.12.1)
# Collecting sox (from nemo_toolkit[asr]==1.23.0)
#   Using cached sox-1.5.0.tar.gz (63 kB)
#   Preparing metadata (setup.py) ... done
# Collecting texterrors (from nemo_toolkit[asr]==1.23.0)
#   Using cached texterrors-0.5.1.tar.gz (23 kB)
#   Preparing metadata (setup.py) ... done
# Collecting hydra-core<=1.3.2,>1.3 (from nemo_toolkit[asr]==1.23.0)
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: omegaconf<=2.3 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (2.3.0)
# Collecting pytorch-lightning<=2.0.7,>=2.0 (from nemo_toolkit[asr]==1.23.0)
#   Using cached pytorch_lightning-2.0.7-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: torchmetrics>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (1.4.1)
# Requirement already satisfied: transformers>=4.36.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (4.39.3)
# Collecting wandb (from nemo_toolkit[asr]==1.23.0)
#   Using cached wandb-0.17.6-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting webdataset<=0.1.62,>=0.1.48 (from nemo_toolkit[asr]==1.23.0)
#   Using cached webdataset-0.1.62-py3-none-any.whl.metadata (5.7 kB)
# Collecting datasets (from nemo_toolkit[asr]==1.23.0)
#   Using cached datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (7.3.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (2.1.4)
# Collecting sacremoses>=0.0.43 (from nemo_toolkit[asr]==1.23.0)
#   Using cached sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: sentencepiece<1.0.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]==1.23.0) (0.1.99)
# Collecting youtokentome>=1.0.5 (from nemo_toolkit[asr]==1.23.0)
#   Using cached youtokentome-1.0.6.tar.gz (86 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core<=1.3.2,>1.3->nemo_toolkit[asr]==1.23.0) (4.9.3)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from lhotse>=1.20.0->nemo_toolkit[asr]==1.23.0) (3.0.1)
# Requirement already satisfied: click>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from lhotse>=1.20.0->nemo_toolkit[asr]==1.23.0) (8.1.7)
# Collecting cytoolz>=0.10.1 (from lhotse>=1.20.0->nemo_toolkit[asr]==1.23.0)
#   Using cached cytoolz-0.12.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Collecting intervaltree>=3.1.0 (from lhotse>=1.20.0->nemo_toolkit[asr]==1.23.0)
#   Using cached intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from lhotse>=1.20.0->nemo_toolkit[asr]==1.23.0) (6.0.2)
# Requirement already satisfied: tabulate>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from lhotse>=1.20.0->nemo_toolkit[asr]==1.23.0) (0.9.0)
# Collecting lilcom>=1.1.0 (from lhotse>=1.20.0->nemo_toolkit[asr]==1.23.0)
#   Using cached lilcom-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->nemo_toolkit[asr]==1.23.0) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->nemo_toolkit[asr]==1.23.0) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->nemo_toolkit[asr]==1.23.0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->nemo_toolkit[asr]==1.23.0) (0.4.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->nemo_toolkit[asr]==1.23.0) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->nemo_toolkit[asr]==1.23.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->nemo_toolkit[asr]==1.23.0) (1.0.8)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (0.43.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.7.0->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (3.20.3)
# Requirement already satisfied: fsspec>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning<=2.0.7,>=2.0->nemo_toolkit[asr]==1.23.0) (2024.6.1)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning<=2.0.7,>=2.0->nemo_toolkit[asr]==1.23.0) (0.11.6)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacremoses>=0.0.43->nemo_toolkit[asr]==1.23.0) (2024.5.15)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile->nemo_toolkit[asr]==1.23.0) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (12.6.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.36.0->nemo_toolkit[asr]==1.23.0) (2.32.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.36.0->nemo_toolkit[asr]==1.23.0) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.36.0->nemo_toolkit[asr]==1.23.0) (0.4.4)
# Collecting pyarrow>=15.0.0 (from datasets->nemo_toolkit[asr]==1.23.0)
#   Using cached pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->nemo_toolkit[asr]==1.23.0)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets->nemo_toolkit[asr]==1.23.0)
#   Using cached xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets->nemo_toolkit[asr]==1.23.0)
#   Using cached multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->nemo_toolkit[asr]==1.23.0) (3.10.2)
# Requirement already satisfied: nltk>=3.2.4 in /usr/local/lib/python3.10/dist-packages (from g2p-en->nemo_toolkit[asr]==1.23.0) (3.8.1)
# Collecting distance>=0.1.3 (from g2p-en->nemo_toolkit[asr]==1.23.0)
#   Using cached Distance-0.1.3.tar.gz (180 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: more-itertools>=8.5.0 in /usr/local/lib/python3.10/dist-packages (from inflect->nemo_toolkit[asr]==1.23.0) (10.3.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from inflect->nemo_toolkit[asr]==1.23.0) (4.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->nemo_toolkit[asr]==1.23.0) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->nemo_toolkit[asr]==1.23.0) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->nemo_toolkit[asr]==1.23.0) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->nemo_toolkit[asr]==1.23.0) (3.6.8)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->nemo_toolkit[asr]==1.23.0) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->nemo_toolkit[asr]==1.23.0) (3.0.11)
# Collecting rapidfuzz<4,>=3 (from jiwer->nemo_toolkit[asr]==1.23.0)
#   Using cached rapidfuzz-3.9.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nemo_toolkit[asr]==1.23.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nemo_toolkit[asr]==1.23.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nemo_toolkit[asr]==1.23.0) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nemo_toolkit[asr]==1.23.0) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nemo_toolkit[asr]==1.23.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nemo_toolkit[asr]==1.23.0) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nemo_toolkit[asr]==1.23.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nemo_toolkit[asr]==1.23.0) (2024.1)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from pyannote.core->nemo_toolkit[asr]==1.23.0) (2.4.0)
# Requirement already satisfied: pyannote.database>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics->nemo_toolkit[asr]==1.23.0) (5.1.0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics->nemo_toolkit[asr]==1.23.0) (0.6.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.10/dist-packages (from pyloudnorm->nemo_toolkit[asr]==1.23.0) (1.0.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from ruamel.yaml->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (0.2.8)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (3.0.3)
# Collecting pybind11 (from texterrors->nemo_toolkit[asr]==1.23.0)
#   Using cached pybind11-2.13.4-py3-none-any.whl.metadata (9.5 kB)
# Collecting plac (from texterrors->nemo_toolkit[asr]==1.23.0)
#   Using cached plac-1.4.3-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting loguru (from texterrors->nemo_toolkit[asr]==1.23.0)
#   Using cached loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from texterrors->nemo_toolkit[asr]==1.23.0) (2.4.0)
# Collecting Levenshtein (from texterrors->nemo_toolkit[asr]==1.23.0)
#   Using cached Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb->nemo_toolkit[asr]==1.23.0)
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb->nemo_toolkit[asr]==1.23.0)
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb->nemo_toolkit[asr]==1.23.0) (4.2.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->nemo_toolkit[asr]==1.23.0) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb->nemo_toolkit[asr]==1.23.0)
#   Using cached sentry_sdk-2.13.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting setproctitle (from wandb->nemo_toolkit[asr]==1.23.0)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile->nemo_toolkit[asr]==1.23.0) (2.22)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from cytoolz>=0.10.1->lhotse>=1.20.0->nemo_toolkit[asr]==1.23.0) (0.12.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]==1.23.0) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]==1.23.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]==1.23.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]==1.23.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]==1.23.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]==1.23.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->nemo_toolkit[asr]==1.23.0) (4.0.3)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb->nemo_toolkit[asr]==1.23.0)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]==1.23.0) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]==1.23.0) (6.3.3)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]==1.23.0)
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (4.9.0)
# Requirement already satisfied: typer>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]==1.23.0) (0.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.36.0->nemo_toolkit[asr]==1.23.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.36.0->nemo_toolkit[asr]==1.23.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.36.0->nemo_toolkit[asr]==1.23.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.36.0->nemo_toolkit[asr]==1.23.0) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->nemo_toolkit==1.23.0->nemo_toolkit[asr]==1.23.0) (2.1.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (6.5.5)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->nemo_toolkit[asr]==1.23.0)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (0.8.4)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]==1.23.0) (1.1.0)
# ...
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed Levenshtein-0.25.1 braceexpand-0.1.7 cytoolz-0.12.3 datasets-2.21.0 dill-0.3.8 distance-0.1.3 docker-pycreds-0.4.0 g2p-en-2.1.0 gitdb-4.0.11 gitpython-3.1.43 hydra-core-1.3.2 intervaltree-3.1.0 jedi-0.19.1 jiwer-3.0.4 kaldi-python-io-1.2.2 kaldiio-2.18.0 lhotse-1.26.0 lilcom-1.8.0 loguru-0.7.2 marshmallow-3.21.3 multiprocess-0.70.16 nemo_toolkit-1.23.0 onnx-1.16.2 plac-1.4.3 pyarrow-17.0.0 pybind11-2.13.4 pydub-0.25.1 pyloudnorm-0.1.1 pytorch-lightning-2.0.7 rapidfuzz-3.9.6 resampy-0.4.3 sacremoses-0.1.1 sentry-sdk-2.13.0 setproctitle-1.3.3 smmap-5.0.1 sox-1.5.0 texterrors-0.5.1 wandb-0.17.6 webdataset-0.1.62 wget-3.2 xxhash-3.4.1 youtokentome-1.0.6
# Collecting demucs
#   Cloning https://github.com/facebookresearch/demucs to /tmp/pip-install-7qbrbj_9/demucs_1887eab6ab1e4d879c700040e77d88e2
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/demucs /tmp/pip-install-7qbrbj_9/demucs_1887eab6ab1e4d879c700040e77d88e2
#   Resolved https://github.com/facebookresearch/demucs to commit e976d93ecc3865e5757426930257e200846a520a
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: demucs
#   Building wheel for demucs (setup.py) ... done
#   Created wheel for demucs: filename=demucs-4.1.0a2-py3-none-any.whl size=83540 sha256=b03db568a774ad9f5374046abe46dee8f0c56b44649d95551cc51c9e1298d128
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kfafx9oj/wheels/45/e4/ca/7791f04b554e5433713e22900eaf11595e27c454fb65ac30ab
# Successfully built demucs
# Installing collected packages: demucs
# Successfully installed demucs-4.1.0a2
# Collecting git+https://github.com/oliverguhr/deepmultilingualpunctuation.git
#   Cloning https://github.com/oliverguhr/deepmultilingualpunctuation.git to /tmp/pip-req-build-tk8grymk
#   Running command git clone --filter=blob:none --quiet https://github.com/oliverguhr/deepmultilingualpunctuation.git /tmp/pip-req-build-tk8grymk
#   Resolved https://github.com/oliverguhr/deepmultilingualpunctuation.git to commit 5a0dd7f4fd56687f59405aa8eba1144393d8b74b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from deepmultilingualpunctuation==1.0.1) (4.39.3)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from deepmultilingualpunctuation==1.0.1) (2.3.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (12.6.20)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers->deepmultilingualpunctuation==1.0.1) (0.23.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers->deepmultilingualpunctuation==1.0.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->deepmultilingualpunctuation==1.0.1) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->deepmultilingualpunctuation==1.0.1) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->deepmultilingualpunctuation==1.0.1) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->deepmultilingualpunctuation==1.0.1) (2.32.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->deepmultilingualpunctuation==1.0.1) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->deepmultilingualpunctuation==1.0.1) (0.4.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->deepmultilingualpunctuation==1.0.1) (4.66.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->deepmultilingualpunctuation==1.0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->deepmultilingualpunctuation==1.0.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->deepmultilingualpunctuation==1.0.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->deepmultilingualpunctuation==1.0.1) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->deepmultilingualpunctuation==1.0.1) (1.3.0)
# Building wheels for collected packages: deepmultilingualpunctuation
#   Building wheel for deepmultilingualpunctuation (setup.py) ... done
#   Created wheel for deepmultilingualpunctuation: filename=deepmultilingualpunctuation-1.0.1-py3-none-any.whl size=5798 sha256=ebc0f9306c26475caeec9dd1ac38412b8ca14fe9cbb30a5fb32018decba0411c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5_4kza8p/wheels/13/14/09/4bbf99cee96e2fbcc7491b5d9087165f0e7f869d276aaa0ec5
# Successfully built deepmultilingualpunctuation
# Installing collected packages: deepmultilingualpunctuation
# Successfully installed deepmultilingualpunctuation-1.0.1
# Collecting git+https://github.com/MahmoudAshraf97/ctc-forced-aligner.git
#   Cloning https://github.com/MahmoudAshraf97/ctc-forced-aligner.git to /tmp/pip-req-build-posyq329
#   Running command git clone --filter=blob:none --quiet https://github.com/MahmoudAshraf97/ctc-forced-aligner.git /tmp/pip-req-build-posyq329
#   Resolved https://github.com/MahmoudAshraf97/ctc-forced-aligner.git to commit abd458dd879305566cd4ed0c8624c95f22e3126a
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from ctc-forced-aligner==0.2) (3.8.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from ctc-forced-aligner==0.2) (2.3.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from ctc-forced-aligner==0.2) (2.3.1+cu121)
# Requirement already satisfied: transformers>=4.34 in /usr/local/lib/python3.10/dist-packages (from ctc-forced-aligner==0.2) (4.39.3)
# Collecting Unidecode (from ctc-forced-aligner==0.2)
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.2) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.2) (0.23.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.2) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.2) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.2) (2.32.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.2) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.2) (0.4.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.2) (4.66.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->ctc-forced-aligner==0.2) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->ctc-forced-aligner==0.2) (1.4.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->ctc-forced-aligner==0.2) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->ctc-forced-aligner==0.2) (12.6.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->ctc-forced-aligner==0.2) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.34->ctc-forced-aligner==0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.34->ctc-forced-aligner==0.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.34->ctc-forced-aligner==0.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.34->ctc-forced-aligner==0.2) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->ctc-forced-aligner==0.2) (1.3.0)
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.8 MB/s eta 0:00:00
# Building wheels for collected packages: ctc-forced-aligner
#   Building wheel for ctc-forced-aligner (pyproject.toml) ... done
#   Created wheel for ctc-forced-aligner: filename=ctc_forced_aligner-0.2-cp310-cp310-linux_x86_64.whl size=1134155 sha256=fe5248981f639445164728bfa696b296f5f723bf1b78f7a8f73262d5ca859c92
#   Stored in directory: /tmp/pip-ephem-wheel-cache-he0pz8i_/wheels/1c/98/3b/f4b23220ebc8d8d2357d6d743a779511a220572d2103ab9060
# Successfully built ctc-forced-aligner
# Installing collected packages: Unidecode, ctc-forced-aligner
# Successfully installed Unidecode-1.3.8 ctc-forced-aligner-0.2

# %%
import os
import wget
from omegaconf import OmegaConf
import json
import shutil
import torch
import torchaudio
from nemo.collections.asr.models.msdd_models import NeuralDiarizer
from deepmultilingualpunctuation import PunctuationModel
import re
import logging
import nltk
from whisperx.utils import LANGUAGES, TO_LANGUAGE_CODE
from ctc_forced_aligner import (
    load_alignment_model,
    generate_emissions,
    preprocess_text,
    get_alignments,
    get_spans,
    postprocess_results,
)
# Out:
# [NeMo W 2024-08-15 20:36:27 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#       torchaudio.set_audio_backend("soundfile")

# %% [markdown]
# # Helper Functions

# %%
punct_model_langs = [
    "en",
    "fr",
    "de",
    "es",
    "it",
    "nl",
    "pt",
    "bg",
    "pl",
    "cs",
    "sk",
    "sl",
]
langs_to_iso = {
    "af": "afr",
    "am": "amh",
    "ar": "ara",
    "as": "asm",
    "az": "aze",
    "ba": "bak",
    "be": "bel",
    "bg": "bul",
    "bn": "ben",
    "bo": "tib",
    "br": "bre",
    "bs": "bos",
    "ca": "cat",
    "cs": "cze",
    "cy": "wel",
    "da": "dan",
    "de": "ger",
    "el": "gre",
    "en": "eng",
    "es": "spa",
    "et": "est",
    "eu": "baq",
    "fa": "per",
    "fi": "fin",
    "fo": "fao",
    "fr": "fre",
    "gl": "glg",
    "gu": "guj",
    "ha": "hau",
    "haw": "haw",
    "he": "heb",
    "hi": "hin",
    "hr": "hrv",
    "ht": "hat",
    "hu": "hun",
    "hy": "arm",
    "id": "ind",
    "is": "ice",
    "it": "ita",
    "ja": "jpn",
    "jw": "jav",
    "ka": "geo",
    "kk": "kaz",
    "km": "khm",
    "kn": "kan",
    "ko": "kor",
    "la": "lat",
    "lb": "ltz",
    "ln": "lin",
    "lo": "lao",
    "lt": "lit",
    "lv": "lav",
    "mg": "mlg",
    "mi": "mao",
    "mk": "mac",
    "ml": "mal",
    "mn": "mon",
    "mr": "mar",
    "ms": "may",
    "mt": "mlt",
    "my": "bur",
    "ne": "nep",
    "nl": "dut",
    "nn": "nno",
    "no": "nor",
    "oc": "oci",
    "pa": "pan",
    "pl": "pol",
    "ps": "pus",
    "pt": "por",
    "ro": "rum",
    "ru": "rus",
    "sa": "san",
    "sd": "snd",
    "si": "sin",
    "sk": "slo",
    "sl": "slv",
    "sn": "sna",
    "so": "som",
    "sq": "alb",
    "sr": "srp",
    "su": "sun",
    "sv": "swe",
    "sw": "swa",
    "ta": "tam",
    "te": "tel",
    "tg": "tgk",
    "th": "tha",
    "tk": "tuk",
    "tl": "tgl",
    "tr": "tur",
    "tt": "tat",
    "uk": "ukr",
    "ur": "urd",
    "uz": "uzb",
    "vi": "vie",
    "yi": "yid",
    "yo": "yor",
    "yue": "yue",
    "zh": "chi",
}


whisper_langs = sorted(LANGUAGES.keys()) + sorted(
    [k.title() for k in TO_LANGUAGE_CODE.keys()]
)


def create_config(output_dir):
    DOMAIN_TYPE = "telephonic"  # Can be meeting, telephonic, or general based on domain type of the audio file
    CONFIG_FILE_NAME = f"diar_infer_{DOMAIN_TYPE}.yaml"
    CONFIG_URL = f"https://raw.githubusercontent.com/NVIDIA/NeMo/main/examples/speaker_tasks/diarization/conf/inference/{CONFIG_FILE_NAME}"
    MODEL_CONFIG = os.path.join(output_dir, CONFIG_FILE_NAME)
    if not os.path.exists(MODEL_CONFIG):
        MODEL_CONFIG = wget.download(CONFIG_URL, output_dir)

    config = OmegaConf.load(MODEL_CONFIG)

    data_dir = os.path.join(output_dir, "data")
    os.makedirs(data_dir, exist_ok=True)

    meta = {
        "audio_filepath": os.path.join(output_dir, "mono_file.wav"),
        "offset": 0,
        "duration": None,
        "label": "infer",
        "text": "-",
        "rttm_filepath": None,
        "uem_filepath": None,
    }
    with open(os.path.join(data_dir, "input_manifest.json"), "w") as fp:
        json.dump(meta, fp)
        fp.write("\n")

    pretrained_vad = "vad_multilingual_marblenet"
    pretrained_speaker_model = "titanet_large"
    config.num_workers = 0  # Workaround for multiprocessing hanging with ipython issue
    config.diarizer.manifest_filepath = os.path.join(data_dir, "input_manifest.json")
    config.diarizer.out_dir = (
        output_dir  # Directory to store intermediate files and prediction outputs
    )

    config.diarizer.speaker_embeddings.model_path = pretrained_speaker_model
    config.diarizer.oracle_vad = (
        False  # compute VAD provided with model_path to vad config
    )
    config.diarizer.clustering.parameters.oracle_num_speakers = False

    # Here, we use our in-house pretrained NeMo VAD model
    config.diarizer.vad.model_path = pretrained_vad
    config.diarizer.vad.parameters.onset = 0.8
    config.diarizer.vad.parameters.offset = 0.6
    config.diarizer.vad.parameters.pad_offset = -0.05
    config.diarizer.msdd_model.model_path = (
        "diar_msdd_telephonic"  # Telephonic speaker diarization model
    )

    return config


def get_word_ts_anchor(s, e, option="start"):
    if option == "end":
        return e
    elif option == "mid":
        return (s + e) / 2
    return s


def get_words_speaker_mapping(wrd_ts, spk_ts, word_anchor_option="start"):
    s, e, sp = spk_ts[0]
    wrd_pos, turn_idx = 0, 0
    wrd_spk_mapping = []
    for wrd_dict in wrd_ts:
        ws, we, wrd = (
            int(wrd_dict["start"] * 1000),
            int(wrd_dict["end"] * 1000),
            wrd_dict["text"],
        )
        wrd_pos = get_word_ts_anchor(ws, we, word_anchor_option)
        while wrd_pos > float(e):
            turn_idx += 1
            turn_idx = min(turn_idx, len(spk_ts) - 1)
            s, e, sp = spk_ts[turn_idx]
            if turn_idx == len(spk_ts) - 1:
                e = get_word_ts_anchor(ws, we, option="end")
        wrd_spk_mapping.append(
            {"word": wrd, "start_time": ws, "end_time": we, "speaker": sp}
        )
    return wrd_spk_mapping


sentence_ending_punctuations = ".?!"


def get_first_word_idx_of_sentence(word_idx, word_list, speaker_list, max_words):
    is_word_sentence_end = (
        lambda x: x >= 0 and word_list[x][-1] in sentence_ending_punctuations
    )
    left_idx = word_idx
    while (
        left_idx > 0
        and word_idx - left_idx < max_words
        and speaker_list[left_idx - 1] == speaker_list[left_idx]
        and not is_word_sentence_end(left_idx - 1)
    ):
        left_idx -= 1

    return left_idx if left_idx == 0 or is_word_sentence_end(left_idx - 1) else -1


def get_last_word_idx_of_sentence(word_idx, word_list, max_words):
    is_word_sentence_end = (
        lambda x: x >= 0 and word_list[x][-1] in sentence_ending_punctuations
    )
    right_idx = word_idx
    while (
        right_idx < len(word_list) - 1
        and right_idx - word_idx < max_words
        and not is_word_sentence_end(right_idx)
    ):
        right_idx += 1

    return (
        right_idx
        if right_idx == len(word_list) - 1 or is_word_sentence_end(right_idx)
        else -1
    )


def get_realigned_ws_mapping_with_punctuation(
    word_speaker_mapping, max_words_in_sentence=50
):
    is_word_sentence_end = (
        lambda x: x >= 0
        and word_speaker_mapping[x]["word"][-1] in sentence_ending_punctuations
    )
    wsp_len = len(word_speaker_mapping)

    words_list, speaker_list = [], []
    for k, line_dict in enumerate(word_speaker_mapping):
        word, speaker = line_dict["word"], line_dict["speaker"]
        words_list.append(word)
        speaker_list.append(speaker)

    k = 0
    while k < len(word_speaker_mapping):
        line_dict = word_speaker_mapping[k]
        if (
            k < wsp_len - 1
            and speaker_list[k] != speaker_list[k + 1]
            and not is_word_sentence_end(k)
        ):
            left_idx = get_first_word_idx_of_sentence(
                k, words_list, speaker_list, max_words_in_sentence
            )
            right_idx = (
                get_last_word_idx_of_sentence(
                    k, words_list, max_words_in_sentence - k + left_idx - 1
                )
                if left_idx > -1
                else -1
            )
            if min(left_idx, right_idx) == -1:
                k += 1
                continue

            spk_labels = speaker_list[left_idx : right_idx + 1]
            mod_speaker = max(set(spk_labels), key=spk_labels.count)
            if spk_labels.count(mod_speaker) < len(spk_labels) // 2:
                k += 1
                continue

            speaker_list[left_idx : right_idx + 1] = [mod_speaker] * (
                right_idx - left_idx + 1
            )
            k = right_idx

        k += 1

    k, realigned_list = 0, []
    while k < len(word_speaker_mapping):
        line_dict = word_speaker_mapping[k].copy()
        line_dict["speaker"] = speaker_list[k]
        realigned_list.append(line_dict)
        k += 1

    return realigned_list


def get_sentences_speaker_mapping(word_speaker_mapping, spk_ts):
    sentence_checker = nltk.tokenize.PunktSentenceTokenizer().text_contains_sentbreak
    s, e, spk = spk_ts[0]
    prev_spk = spk

    snts = []
    snt = {"speaker": f"Speaker {spk}", "start_time": s, "end_time": e, "text": ""}

    for wrd_dict in word_speaker_mapping:
        wrd, spk = wrd_dict["word"], wrd_dict["speaker"]
        s, e = wrd_dict["start_time"], wrd_dict["end_time"]
        if spk != prev_spk or sentence_checker(snt["text"] + " " + wrd):
            snts.append(snt)
            snt = {
                "speaker": f"Speaker {spk}",
                "start_time": s,
                "end_time": e,
                "text": "",
            }
        else:
            snt["end_time"] = e
        snt["text"] += wrd + " "
        prev_spk = spk

    snts.append(snt)
    return snts


def get_speaker_aware_transcript(sentences_speaker_mapping, f):
    previous_speaker = sentences_speaker_mapping[0]["speaker"]
    f.write(f"{previous_speaker}: ")

    for sentence_dict in sentences_speaker_mapping:
        speaker = sentence_dict["speaker"]
        sentence = sentence_dict["text"]

        # If this speaker doesn't match the previous one, start a new paragraph
        if speaker != previous_speaker:
            f.write(f"\n\n{speaker}: ")
            previous_speaker = speaker

        # No matter what, write the current sentence
        f.write(sentence + " ")


def format_timestamp(
    milliseconds: float, always_include_hours: bool = False, decimal_marker: str = "."
):
    assert milliseconds >= 0, "non-negative timestamp expected"

    hours = milliseconds // 3_600_000
    milliseconds -= hours * 3_600_000

    minutes = milliseconds // 60_000
    milliseconds -= minutes * 60_000

    seconds = milliseconds // 1_000
    milliseconds -= seconds * 1_000

    hours_marker = f"{hours:02d}:" if always_include_hours or hours > 0 else ""
    return (
        f"{hours_marker}{minutes:02d}:{seconds:02d}{decimal_marker}{milliseconds:03d}"
    )


def write_srt(transcript, file):
    """
    Write a transcript to a file in SRT format.

    """
    for i, segment in enumerate(transcript, start=1):
        # write srt lines
        print(
            f"{i}\n"
            f"{format_timestamp(segment['start_time'], always_include_hours=True, decimal_marker=',')} --> "
            f"{format_timestamp(segment['end_time'], always_include_hours=True, decimal_marker=',')}\n"
            f"{segment['speaker']}: {segment['text'].strip().replace('-->', '->')}\n",
            file=file,
            flush=True,
        )


def find_numeral_symbol_tokens(tokenizer):
    numeral_symbol_tokens = [
        -1,
    ]
    for token, token_id in tokenizer.get_vocab().items():
        has_numeral_symbol = any(c in "0123456789%$£" for c in token)
        if has_numeral_symbol:
            numeral_symbol_tokens.append(token_id)
    return numeral_symbol_tokens


def _get_next_start_timestamp(word_timestamps, current_word_index, final_timestamp):
    # if current word is the last word
    if current_word_index == len(word_timestamps) - 1:
        return word_timestamps[current_word_index]["start"]

    next_word_index = current_word_index + 1
    while current_word_index < len(word_timestamps) - 1:
        if word_timestamps[next_word_index].get("start") is None:
            # if next word doesn't have a start timestamp
            # merge it with the current word and delete it
            word_timestamps[current_word_index]["word"] += (
                " " + word_timestamps[next_word_index]["word"]
            )

            word_timestamps[next_word_index]["word"] = None
            next_word_index += 1
            if next_word_index == len(word_timestamps):
                return final_timestamp

        else:
            return word_timestamps[next_word_index]["start"]


def filter_missing_timestamps(
    word_timestamps, initial_timestamp=0, final_timestamp=None
):
    # handle the first and last word
    if word_timestamps[0].get("start") is None:
        word_timestamps[0]["start"] = (
            initial_timestamp if initial_timestamp is not None else 0
        )
        word_timestamps[0]["end"] = _get_next_start_timestamp(
            word_timestamps, 0, final_timestamp
        )

    result = [
        word_timestamps[0],
    ]

    for i, ws in enumerate(word_timestamps[1:], start=1):
        # if ws doesn't have a start and end
        # use the previous end as start and next start as end
        if ws.get("start") is None and ws.get("word") is not None:
            ws["start"] = word_timestamps[i - 1]["end"]
            ws["end"] = _get_next_start_timestamp(word_timestamps, i, final_timestamp)

        if ws["word"] is not None:
            result.append(ws)
    return result


def cleanup(path: str):
    """path could either be relative or absolute."""
    # check if file or directory exists
    if os.path.isfile(path) or os.path.islink(path):
        # remove file
        os.remove(path)
    elif os.path.isdir(path):
        # remove directory and all its content
        shutil.rmtree(path)
    else:
        raise ValueError("Path {} is not a file or dir.".format(path))


def process_language_arg(language: str, model_name: str):
    """
    Process the language argument to make sure it's valid and convert language names to language codes.
    """
    if language is not None:
        language = language.lower()
    if language not in LANGUAGES:
        if language in TO_LANGUAGE_CODE:
            language = TO_LANGUAGE_CODE[language]
        else:
            raise ValueError(f"Unsupported language: {language}")

    if model_name.endswith(".en") and language != "en":
        if language is not None:
            logging.warning(
                f"{model_name} is an English-only model but received '{language}'; using English instead."
            )
        language = "en"
    return language


def transcribe_batched(
    audio_file: str,
    language: str,
    batch_size: int,
    model_name: str,
    compute_dtype: str,
    suppress_numerals: bool,
    device: str,
):
    import whisperx

    # Faster Whisper batched
    whisper_model = whisperx.load_model(
        model_name,
        device,
        compute_type=compute_dtype,
        asr_options={"suppress_numerals": suppress_numerals},
    )
    audio = whisperx.load_audio(audio_file)
    result = whisper_model.transcribe(audio, language=language, batch_size=batch_size)
    del whisper_model
    torch.cuda.empty_cache()
    return result["segments"], result["language"], audio

# %% [markdown]
# # Options

# %%
# Name of the audio file
audio_path = "/content/Michael Levin： Biology, Life, Aliens, Evolution, Embryogenesis & Xenobots ｜ Lex Fridman Podcast #325.mp3"

# Whether to enable music removal from speech, helps increase diarization quality but uses alot of ram
enable_stemming = True

# (choose from 'tiny.en', 'tiny', 'base.en', 'base', 'small.en', 'small', 'medium.en', 'medium', 'large-v1', 'large-v2', 'large-v3', 'large')
whisper_model_name = "large-v1"

# replaces numerical digits with their pronounciation, increases diarization accuracy
suppress_numerals = True

batch_size = 4

language = None  # autodetect language

device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# # Processing

# %% [markdown]
# ## Separating music from speech using Demucs
#
# ---
#
# By isolating the vocals from the rest of the audio, it becomes easier to identify and track individual speakers based on the spectral and temporal characteristics of their speech signals. Source separation is just one of many techniques that can be used as a preprocessing step to help improve the accuracy and reliability of the overall diarization process.

# %%
if enable_stemming:
    # Isolate vocals from the rest of the audio

    return_code = os.system(
        f'python3 -m demucs.separate -n htdemucs --two-stems=vocals "{audio_path}" -o "temp_outputs"'
    )

    if return_code != 0:
        logging.warning("Source splitting failed, using original audio file.")
        vocal_target = audio_path
    else:
        vocal_target = os.path.join(
            "temp_outputs",
            "htdemucs",
            os.path.splitext(os.path.basename(audio_path))[0],
            "vocals.wav",
        )
else:
    vocal_target = audio_path
# Out:
# WARNING:root:Source splitting failed, using original audio file.

# %% [markdown]
# ## Transcriping audio using Whisper and realligning timestamps using Wav2Vec2
# ---
# This code uses two different open-source models to transcribe speech and perform forced alignment on the resulting transcription.
#
# The first model is called OpenAI Whisper, which is a speech recognition model that can transcribe speech with high accuracy. The code loads the whisper model and uses it to transcribe the vocal_target file.
#
# The output of the transcription process is a set of text segments with corresponding timestamps indicating when each segment was spoken.

# %%
#compute_type = "float16"
# or run on GPU with INT8
# compute_type = "int8_float16"
# or run on CPU with INT8
compute_type = "int8"

whisper_results, language, audio_waveform = transcribe_batched(
    vocal_target,
    language,
    batch_size,
    whisper_model_name,
    compute_type,
    suppress_numerals,
    device,
)
# Out:
# config.json:   0%|          | 0.00/2.35k [00:00<?, ?B/s]
# vocabulary.txt:   0%|          | 0.00/460k [00:00<?, ?B/s]
# model.bin:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.20M [00:00<?, ?B/s]
# No language specified, language will be first be detected for each audio file (increases inference time).
# 100%|█████████████████████████████████████| 16.9M/16.9M [00:01<00:00, 17.1MiB/s]
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.0.7. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../root/.cache/torch/whisperx-vad-segmentation.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.3.1+cu121. Bad things might happen unless you revert torch to 1.x.
# Detected language: en (1.00) in first 30s of audio...
# Suppressing numeral and symbol tokens

# %% [markdown]
# ## Aligning the transcription with the original audio using Wav2Vec2
# ---
# The second model used is called wav2vec2, which is a large-scale neural network that is designed to learn representations of speech that are useful for a variety of speech processing tasks, including speech recognition and alignment.
#
# The code loads the wav2vec2 alignment model and uses it to align the transcription segments with the original audio signal contained in the vocal_target file. This process involves finding the exact timestamps in the audio signal where each segment was spoken and aligning the text accordingly.
#
# By combining the outputs of the two models, the code produces a fully aligned transcription of the speech contained in the vocal_target file. This aligned transcription can be useful for a variety of speech processing tasks, such as speaker diarization, sentiment analysis, and language identification.
#
# If there's no Wav2Vec2 model available for your language, word timestamps generated by whisper will be used instead.

# %%
alignment_model, alignment_tokenizer, alignment_dictionary = load_alignment_model(
    device,
    dtype=torch.float16 if device == "cuda" else torch.float32,
)

audio_waveform = (
    torch.from_numpy(audio_waveform)
    .to(alignment_model.dtype)
    .to(alignment_model.device)
)

emissions, stride = generate_emissions(
    alignment_model, audio_waveform, batch_size=batch_size
)

del alignment_model
torch.cuda.empty_cache()

full_transcript = "".join(segment["text"] for segment in whisper_results)

tokens_starred, text_starred = preprocess_text(
    full_transcript,
    romanize=True,
    language=langs_to_iso[language],
)

segments, scores, blank_id = get_alignments(
    emissions,
    tokens_starred,
    alignment_dictionary,
)

spans = get_spans(tokens_starred, segments, alignment_tokenizer.decode(blank_id))

word_timestamps = postprocess_results(text_starred, spans, stride, scores)
# Out:
# config.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/286 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/74.0 [00:00<?, ?B/s]

# %% [markdown]
# ## Convert audio to mono for NeMo combatibility

# %%
ROOT = os.getcwd()
temp_path = os.path.join(ROOT, "temp_outputs")
os.makedirs(temp_path, exist_ok=True)
torchaudio.save(
    os.path.join(temp_path, "mono_file.wav"),
    audio_waveform.cpu().unsqueeze(0).float(),
    16000,
    channels_first=True,
)

# %% [markdown]
# ## Speaker Diarization using NeMo MSDD Model
# ---
# This code uses a model called Nvidia NeMo MSDD (Multi-scale Diarization Decoder) to perform speaker diarization on an audio signal. Speaker diarization is the process of separating an audio signal into different segments based on who is speaking at any given time.

# %%
# Initialize NeMo MSDD diarization model
msdd_model = NeuralDiarizer(cfg=create_config(temp_path)).to("cuda")
msdd_model.diarize()

del msdd_model
torch.cuda.empty_cache()
# Out:
# [NeMo I 2024-08-15 21:04:43 msdd_models:1092] Loading pretrained diar_msdd_telephonic model from NGC
# [NeMo I 2024-08-15 21:04:43 cloud:68] Downloading from: https://api.ngc.nvidia.com/v2/models/nvidia/nemo/diar_msdd_telephonic/versions/1.0.1/files/diar_msdd_telephonic.nemo to /root/.cache/torch/NeMo/NeMo_1.23.0/diar_msdd_telephonic/3c3697a0a46f945574fa407149975a13/diar_msdd_telephonic.nemo
# [NeMo I 2024-08-15 21:04:44 common:924] Instantiating model from pre-trained checkpoint
# [NeMo W 2024-08-15 21:04:46 modelPT:165] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: null
#     emb_dir: null
#     sample_rate: 16000
#     num_spks: 2
#     soft_label_thres: 0.5
#     labels: null
#     batch_size: 15
#     emb_batch_size: 0
#     shuffle: true
#
# [NeMo W 2024-08-15 21:04:46 modelPT:172] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: null
#     emb_dir: null
#     sample_rate: 16000
#     num_spks: 2
#     soft_label_thres: 0.5
#     labels: null
#     batch_size: 15
#     emb_batch_size: 0
#     shuffle: false
#
# [NeMo W 2024-08-15 21:04:46 modelPT:178] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     emb_dir: null
#     sample_rate: 16000
#     num_spks: 2
#     soft_label_thres: 0.5
#     labels: null
#     batch_size: 15
#     emb_batch_size: 0
#     shuffle: false
#     seq_eval_mode: false
# [NeMo I 2024-08-15 21:04:46 features:289] PADDING: 16
# [NeMo I 2024-08-15 21:04:46 features:289] PADDING: 16
# [NeMo I 2024-08-15 21:04:47 save_restore_connector:249] Model EncDecDiarLabelModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.23.0/diar_msdd_telephonic/3c3697a0a46f945574fa407149975a13/diar_msdd_telephonic.nemo.
# [NeMo I 2024-08-15 21:04:47 features:289] PADDING: 16
# [NeMo I 2024-08-15 21:04:47 clustering_diarizer:127] Loading pretrained vad_multilingual_marblenet model from NGC
# [NeMo I 2024-08-15 21:04:47 cloud:68] Downloading from: https://api.ngc.nvidia.com/v2/models/nvidia/nemo/vad_multilingual_marblenet/versions/1.10.0/files/vad_multilingual_marblenet.nemo to /root/.cache/torch/NeMo/NeMo_1.23.0/vad_multilingual_marblenet/670f425c7f186060b7a7268ba6dfacb2/vad_multilingual_marblenet.nemo
# [NeMo I 2024-08-15 21:04:48 common:924] Instantiating model from pre-trained checkpoint
# [NeMo W 2024-08-15 21:04:48 modelPT:165] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /manifests/ami_train_0.63.json,/manifests/freesound_background_train.json,/manifests/freesound_laughter_train.json,/manifests/fisher_2004_background.json,/manifests/fisher_2004_speech_sampled.json,/manifests/google_train_manifest.json,/manifests/icsi_all_0.63.json,/manifests/musan_freesound_train.json,/manifests/musan_music_train.json,/manifests/musan_soundbible_train.json,/manifests/mandarin_train_sample.json,/manifests/german_train_sample.json,/manifests/spanish_train_sample.json,/manifests/french_train_sample.json,/manifests/russian_train_sample.json
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 256
#     shuffle: true
#     is_tarred: false
#     tarred_audio_filepaths: null
#     tarred_shard_strategy: scatter
#     augmentor:
#       shift:
#         prob: 0.5
#         min_shift_ms: -10.0
#         max_shift_ms: 10.0
#       white_noise:
#         prob: 0.5
#         min_level: -90
#         max_level: -46
#         norm: true
#       noise:
#         prob: 0.5
#         manifest_path: /manifests/noise_0_1_musan_fs.json
#         min_snr_db: 0
#         max_snr_db: 30
#         max_gain_db: 300.0
#         norm: true
#       gain:
#         prob: 0.5
#         min_gain_dbfs: -10.0
#         max_gain_dbfs: 10.0
#         norm: true
#     num_workers: 16
#     pin_memory: true
#
# [NeMo W 2024-08-15 21:04:48 modelPT:172] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /manifests/ami_dev_0.63.json,/manifests/freesound_background_dev.json,/manifests/freesound_laughter_dev.json,/manifests/ch120_moved_0.63.json,/manifests/fisher_2005_500_speech_sampled.json,/manifests/google_dev_manifest.json,/manifests/musan_music_dev.json,/manifests/mandarin_dev.json,/manifests/german_dev.json,/manifests/spanish_dev.json,/manifests/french_dev.json,/manifests/russian_dev.json
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 256
#     shuffle: false
#     val_loss_idx: 0
#     num_workers: 16
#     pin_memory: true
#
# [NeMo W 2024-08-15 21:04:48 modelPT:178] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 128
#     shuffle: false
#     test_loss_idx: 0
# [NeMo I 2024-08-15 21:04:48 features:289] PADDING: 16
# [NeMo I 2024-08-15 21:04:48 save_restore_connector:249] Model EncDecClassificationModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.23.0/vad_multilingual_marblenet/670f425c7f186060b7a7268ba6dfacb2/vad_multilingual_marblenet.nemo.
# [NeMo I 2024-08-15 21:04:48 msdd_models:864] Multiscale Weights: [1, 1, 1, 1, 1]
# [NeMo I 2024-08-15 21:04:48 msdd_models:865] Clustering Parameters: {
#         "oracle_num_speakers": false,
#         "max_num_speakers": 8,
#         "enhanced_count_thres": 80,
#         "max_rp_threshold": 0.25,
#         "sparse_search_volume": 30,
#         "maj_vote_spk_count": false,
#         "chunk_cluster_count": 50,
#         "embeddings_per_chunk": 10000
#     }
# [NeMo I 2024-08-15 21:04:48 speaker_utils:93] Number of files to diarize: 1
# [NeMo I 2024-08-15 21:04:48 clustering_diarizer:309] Split long audio file to avoid CUDA memory issue
# splitting manifest: 100%|██████████| 1/1 [00:12<00:00, 12.74s/it]
# [NeMo I 2024-08-15 21:05:01 classification_models:273] Perform streaming frame-level VAD
# [NeMo I 2024-08-15 21:05:01 collections:445] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2024-08-15 21:05:01 collections:446] Dataset loaded with 217 items, total duration of  3.01 hours.
# [NeMo I 2024-08-15 21:05:01 collections:448] # 217 files loaded accounting to # 1 labels
# vad: 100%|██████████| 217/217 [00:45<00:00,  4.76it/s]
# [NeMo I 2024-08-15 21:05:47 clustering_diarizer:250] Generating predictions with overlapping input segments
# [NeMo I 2024-08-15 21:07:41 clustering_diarizer:262] Converting frame level prediction to speech/no-speech segment in start and end times format.
# creating speech segments: 100%|██████████| 1/1 [00:08<00:00,  8.66s/it]
# [NeMo I 2024-08-15 21:07:49 clustering_diarizer:287] Subsegmentation for embedding extraction: scale0, /content/temp_outputs/speaker_outputs/subsegments_scale0.json
# [NeMo I 2024-08-15 21:07:50 clustering_diarizer:343] Extracting embeddings for Diarization
# [NeMo I 2024-08-15 21:07:50 collections:445] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2024-08-15 21:07:50 collections:446] Dataset loaded with 12054 items, total duration of  4.76 hours.
# [NeMo I 2024-08-15 21:07:50 collections:448] # 12054 files loaded accounting to # 1 labels
# [1/5] extract embeddings: 100%|██████████| 189/189 [00:21<00:00,  8.85it/s]
# [NeMo I 2024-08-15 21:08:13 clustering_diarizer:389] Saved embedding files to /content/temp_outputs/speaker_outputs/embeddings
# [NeMo I 2024-08-15 21:08:13 clustering_diarizer:287] Subsegmentation for embedding extraction: scale1, /content/temp_outputs/speaker_outputs/subsegments_scale1.json
# [NeMo I 2024-08-15 21:08:13 clustering_diarizer:343] Extracting embeddings for Diarization
# [NeMo I 2024-08-15 21:08:13 collections:445] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2024-08-15 21:08:13 collections:446] Dataset loaded with 14644 items, total duration of  4.87 hours.
# [NeMo I 2024-08-15 21:08:13 collections:448] # 14644 files loaded accounting to # 1 labels
# [2/5] extract embeddings: 100%|██████████| 229/229 [00:21<00:00, 10.84it/s]
# [NeMo I 2024-08-15 21:08:37 clustering_diarizer:389] Saved embedding files to /content/temp_outputs/speaker_outputs/embeddings
# [NeMo I 2024-08-15 21:08:37 clustering_diarizer:287] Subsegmentation for embedding extraction: scale2, /content/temp_outputs/speaker_outputs/subsegments_scale2.json
# [NeMo I 2024-08-15 21:08:37 clustering_diarizer:343] Extracting embeddings for Diarization
# [NeMo I 2024-08-15 21:08:38 collections:445] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2024-08-15 21:08:38 collections:446] Dataset loaded with 18447 items, total duration of  4.96 hours.
# [NeMo I 2024-08-15 21:08:38 collections:448] # 18447 files loaded accounting to # 1 labels
# [3/5] extract embeddings: 100%|██████████| 289/289 [00:24<00:00, 11.65it/s]
# [NeMo I 2024-08-15 21:09:07 clustering_diarizer:389] Saved embedding files to /content/temp_outputs/speaker_outputs/embeddings
# [NeMo I 2024-08-15 21:09:07 clustering_diarizer:287] Subsegmentation for embedding extraction: scale3, /content/temp_outputs/speaker_outputs/subsegments_scale3.json
# [NeMo I 2024-08-15 21:09:07 clustering_diarizer:343] Extracting embeddings for Diarization
# [NeMo I 2024-08-15 21:09:08 collections:445] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2024-08-15 21:09:08 collections:446] Dataset loaded with 24925 items, total duration of  5.07 hours.
# [NeMo I 2024-08-15 21:09:08 collections:448] # 24925 files loaded accounting to # 1 labels
# [4/5] extract embeddings: 100%|██████████| 390/390 [00:29<00:00, 13.29it/s]
# [NeMo I 2024-08-15 21:09:45 clustering_diarizer:389] Saved embedding files to /content/temp_outputs/speaker_outputs/embeddings
# [NeMo I 2024-08-15 21:09:45 clustering_diarizer:287] Subsegmentation for embedding extraction: scale4, /content/temp_outputs/speaker_outputs/subsegments_scale4.json
# [NeMo I 2024-08-15 21:09:45 clustering_diarizer:343] Extracting embeddings for Diarization
# [NeMo I 2024-08-15 21:09:46 collections:445] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2024-08-15 21:09:46 collections:446] Dataset loaded with 37850 items, total duration of  5.18 hours.
# [NeMo I 2024-08-15 21:09:46 collections:448] # 37850 files loaded accounting to # 1 labels
# [5/5] extract embeddings: 100%|██████████| 592/592 [00:39<00:00, 15.05it/s]
# [NeMo I 2024-08-15 21:10:46 clustering_diarizer:389] Saved embedding files to /content/temp_outputs/speaker_outputs/embeddings
# clustering:   0%|          | 0/1 [00:00<?, ?it/s]
# Clustering Sub-Windows:   0%|          | 0/4 [00:00<?, ?window/s]
# Clustering Sub-Windows:  25%|██▌       | 1/4 [00:07<00:21,  7.05s/window]
# Clustering Sub-Windows:  50%|█████     | 2/4 [00:08<00:07,  3.51s/window]
# Clustering Sub-Windows:  75%|███████▌  | 3/4 [00:14<00:04,  4.87s/window]
# Clustering Sub-Windows: 100%|██████████| 4/4 [00:22<00:00,  5.94s/window]
# Clustering Sub-Windows: 5window [00:23,  4.18s/window]
# Clustering Sub-Windows: 100%|██████████| 4/4 [00:31<00:00,  7.75s/window]
# clustering: 100%|██████████| 1/1 [01:18<00:00, 78.19s/it]
# [NeMo I 2024-08-15 21:12:04 clustering_diarizer:464] Outputs are saved in /content/temp_outputs directory
# [NeMo W 2024-08-15 21:12:04 der:185] Check if each ground truth RTTMs were present in the provided manifest file. Skipping calculation of Diariazation Error Rate
# [NeMo I 2024-08-15 21:12:51 msdd_models:960] Loading embedding pickle file of scale:0 at /content/temp_outputs/speaker_outputs/embeddings/subsegments_scale0_embeddings.pkl
# [NeMo I 2024-08-15 21:12:51 msdd_models:960] Loading embedding pickle file of scale:1 at /content/temp_outputs/speaker_outputs/embeddings/subsegments_scale1_embeddings.pkl
# [NeMo I 2024-08-15 21:12:51 msdd_models:960] Loading embedding pickle file of scale:2 at /content/temp_outputs/speaker_outputs/embeddings/subsegments_scale2_embeddings.pkl
# [NeMo I 2024-08-15 21:12:51 msdd_models:960] Loading embedding pickle file of scale:3 at /content/temp_outputs/speaker_outputs/embeddings/subsegments_scale3_embeddings.pkl
# [NeMo I 2024-08-15 21:12:51 msdd_models:960] Loading embedding pickle file of scale:4 at /content/temp_outputs/speaker_outputs/embeddings/subsegments_scale4_embeddings.pkl
# [NeMo I 2024-08-15 21:12:51 msdd_models:938] Loading cluster label file from /content/temp_outputs/speaker_outputs/subsegments_scale4_cluster.label
# [NeMo I 2024-08-15 21:13:02 collections:761] Filtered duration for loading collection is 0.000000.
# [NeMo I 2024-08-15 21:13:02 collections:764] Total 1 session files loaded accounting to # 1 audio clips
# 100%|██████████| 1/1 [00:06<00:00,  6.68s/it]
# [NeMo I 2024-08-15 21:13:08 msdd_models:1403]      [Threshold: 0.7000] [use_clus_as_main=False] [diar_window=50]
# [NeMo I 2024-08-15 21:13:08 speaker_utils:93] Number of files to diarize: 1
# [NeMo I 2024-08-15 21:13:08 speaker_utils:93] Number of files to diarize: 1
# [NeMo W 2024-08-15 21:13:10 der:185] Check if each ground truth RTTMs were present in the provided manifest file. Skipping calculation of Diariazation Error Rate
# [NeMo I 2024-08-15 21:13:10 speaker_utils:93] Number of files to diarize: 1
# [NeMo W 2024-08-15 21:13:12 der:185] Check if each ground truth RTTMs were present in the provided manifest file. Skipping calculation of Diariazation Error Rate
# [NeMo I 2024-08-15 21:13:12 speaker_utils:93] Number of files to diarize: 1
# [NeMo W 2024-08-15 21:13:14 der:185] Check if each ground truth RTTMs were present in the provided manifest file. Skipping calculation of Diariazation Error Rate
# [NeMo I 2024-08-15 21:13:14 msdd_models:1431]

# %% [markdown]
# ## Mapping Spekers to Sentences According to Timestamps

# %%
# Reading timestamps <> Speaker Labels mapping

speaker_ts = []
with open(os.path.join(temp_path, "pred_rttms", "mono_file.rttm"), "r") as f:
    lines = f.readlines()
    for line in lines:
        line_list = line.split(" ")
        s = int(float(line_list[5]) * 1000)
        e = s + int(float(line_list[8]) * 1000)
        speaker_ts.append([s, e, int(line_list[11].split("_")[-1])])

wsm = get_words_speaker_mapping(word_timestamps, speaker_ts, "start")

# %%
wsm
# Out:
# [{'word': 'And', 'start_time': 20, 'end_time': 60, 'speaker': 0},
#  {'word': 'it', 'start_time': 100, 'end_time': 120, 'speaker': 0},
#  {'word': 'turns', 'start_time': 160, 'end_time': 380, 'speaker': 0},
#  {'word': 'out', 'start_time': 440, 'end_time': 540, 'speaker': 0},
#  {'word': 'that', 'start_time': 600, 'end_time': 720, 'speaker': 0},
#  {'word': 'if', 'start_time': 880, 'end_time': 920, 'speaker': 0},
#  {'word': 'you', 'start_time': 980, 'end_time': 1020, 'speaker': 0},
#  {'word': 'train', 'start_time': 1060, 'end_time': 1280, 'speaker': 0},
#  {'word': 'a', 'start_time': 1360, 'end_time': 1360, 'speaker': 0},
#  {'word': 'planaria', 'start_time': 1420, 'end_time': 1840, 'speaker': 0},
#  {'word': 'and', 'start_time': 2040, 'end_time': 2080, 'speaker': 0},
#  {'word': 'then', 'start_time': 2120, 'end_time': 2240, 'speaker': 0},
#  {'word': 'cut', 'start_time': 2520, 'end_time': 2620, 'speaker': 0},
#  {'word': 'their', 'start_time': 2660, 'end_time': 2760, 'speaker': 0},
#  {'word': 'heads', 'start_time': 2800, 'end_time': 2980, 'speaker': 0},
#  {'word': 'off,', 'start_time': 3080, 'end_time': 3200, 'speaker': 0},
#  {'word': 'the', 'start_time': 3600, 'end_time': 3640, 'speaker': 0},
#  {'word': 'tail', 'start_time': 3720, 'end_time': 3960, 'speaker': 0},
#  {'word': 'will', 'start_time': 4019, 'end_time': 4140, 'speaker': 0},
#  {'word': 'regenerate', 'start_time': 4220, 'end_time': 4660, 'speaker': 0},
#  {'word': 'a', 'start_time': 4720, 'end_time': 4720, 'speaker': 0},
#  {'word': 'brand', 'start_time': 4780, 'end_time': 5000, 'speaker': 0},
#  {'word': 'new', 'start_time': 5040, 'end_time': 5120, 'speaker': 0},
#  {'word': 'brain', 'start_time': 5180, 'end_time': 5460, 'speaker': 0},
#  {'word': 'that', 'start_time': 5500, 'end_time': 5600, 'speaker': 0},
#  {'word': 'still', 'start_time': 5680, 'end_time': 5840, 'speaker': 0},
#  {'word': 'remembers', 'start_time': 5900, 'end_time': 6300, 'speaker': 0},
#  {'word': 'the', 'start_time': 6360, 'end_time': 6400, 'speaker': 0},
#  {'word': 'original', 'start_time': 6460, 'end_time': 6780, 'speaker': 0},
#   'end_time': 306120,
#   'speaker': 0},
#  {'word': 'get', 'start_time': 306180, 'end_time': 306280, 'speaker': 0},
#  {'word': 'to', 'start_time': 306340, 'end_time': 306380, 'speaker': 0},
#  {'word': 'use', 'start_time': 306480, 'end_time': 306600, 'speaker': 0},
#  ...]

# %% [markdown]
# ## Realligning Speech segments using Punctuation
# ---
#
# This code provides a method for disambiguating speaker labels in cases where a sentence is split between two different speakers. It uses punctuation markings to determine the dominant speaker for each sentence in the transcription.
#
# ```
# Speaker A: It's got to come from somewhere else. Yeah, that one's also fun because you know the lows are
# Speaker B: going to suck, right? So it's actually it hits you on both sides.
# ```
#
# For example, if a sentence is split between two speakers, the code takes the mode of speaker labels for each word in the sentence, and uses that speaker label for the whole sentence. This can help to improve the accuracy of speaker diarization, especially in cases where the Whisper model may not take fine utterances like "hmm" and "yeah" into account, but the Diarization Model (Nemo) may include them, leading to inconsistent results.
#
# The code also handles cases where one speaker is giving a monologue while other speakers are making occasional comments in the background. It ignores the comments and assigns the entire monologue to the speaker who is speaking the majority of the time. This provides a robust and reliable method for realigning speech segments to their respective speakers based on punctuation in the transcription.

# %%
if language in punct_model_langs:
    # restoring punctuation in the transcript to help realign the sentences
    punct_model = PunctuationModel(model="kredor/punctuate-all")

    words_list = list(map(lambda x: x["word"], wsm))

    labled_words = punct_model.predict(words_list,chunk_size=230)

    ending_puncts = ".?!"
    model_puncts = ".,;:!?"

    # We don't want to punctuate U.S.A. with a period. Right?
    is_acronym = lambda x: re.fullmatch(r"\b(?:[a-zA-Z]\.){2,}", x)

    for word_dict, labeled_tuple in zip(wsm, labled_words):
        word = word_dict["word"]
        if (
            word
            and labeled_tuple[1] in ending_puncts
            and (word[-1] not in model_puncts or is_acronym(word))
        ):
            word += labeled_tuple[1]
            if word.endswith(".."):
                word = word.rstrip(".")
            word_dict["word"] = word

else:
    logging.warning(
        f"Punctuation restoration is not available for {language} language. Using the original punctuation."
    )

wsm = get_realigned_ws_mapping_with_punctuation(wsm)
ssm = get_sentences_speaker_mapping(wsm, speaker_ts)
# Out:
# config.json:   0%|          | 0.00/914 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/447 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 619, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 685, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 738, in _run_callback
#     ret = callback()
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 825, in inner
#     self.ctx_run(self.run)
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#     yielded = self.gen.send(value)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 377, in dispatch_queue
#     yield self.process_one()
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 250, in wrapper
#     runner = Runner(ctx_run, result, future, yielded)
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 748, in __init__
#     self.ctx_run(self.run)
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#     yielded = self.gen.send(value)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#     self.do_execute(
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-b1b4956f5001>", line 7, in <cell line: 1>
#     labled_words = punct_model.predict(words_list,chunk_size=230)
#   File "/usr/local/lib/python3.10/dist-packages/deepmultilingualpunctuation/punctuationmodel.py", line 47, in predict
#     result = self.pipe(text)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py", line 248, in __call__
#     return super().__call__(inputs, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py", line 1167, in __call__
#     logger.warning_once(
#   File "/usr/local/lib/python3.10/dist-packages/transformers/utils/logging.py", line 329, in warning_once
#     self.warning(*args, **kwargs)
# Message: 'You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset'
# Arguments: (<class 'UserWarning'>,)

# %%
ssm
# Out:
# [{'speaker': 'Speaker 0',
#   'start_time': 0,
#   'end_time': 7280,
#   'text': 'And it turns out that if you train a planaria and then cut their heads off, the tail will regenerate a brand new brain that still remembers the original information. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 7780,
#   'end_time': 11740,
#   'text': 'I think planaria hold the answer to pretty much every deep question of life. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 12360,
#   'end_time': 14660,
#   'text': "For one thing, they're similar to our ancestors. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 14700,
#   'end_time': 15560,
#   'text': 'So they have true symmetry. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 15600,
#   'end_time': 16300,
#   'text': 'They have a true brain. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 16340,
#   'end_time': 17160,
#   'text': "They're not like earthworms. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 17220,
#   'end_time': 18860,
#   'text': "They're much more advanced life form. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 19140,
#   'end_time': 24600,
#   'text': "They have lots of different internal organs, but they're these little, they're about maybe two centimeters in the centimeter to two in size. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 25620,
#   'end_time': 26620,
#   'text': 'They have a head and a tail. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 27280,
#   'end_time': 29120,
#   'text': 'And the first thing is planaria are immortal. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 29680,
#   'end_time': 30900,
#   'text': 'So they do not age. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 30960,
#   'end_time': 32360,
#   'text': "There's no such thing as an old planarian. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 32659,
#   'end_time': 37640,
#   'text': 'So that right there tells you that these theories of thermodynamic limitations on lifespan are wrong. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 38320,
#   'end_time': 40600,
#   'text': "It's not that, well, over time, everything degrades. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 40680,
#   'end_time': 44840,
#   'text': 'No, planaria can keep it going for probably how long have they been around? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 44880,
#   'end_time': 45720,
#   'text': 'Four hundred million years. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 47260,
#   'end_time': 52560,
#   'text': 'So the planaria in our lab are actually in physical continuity with planaria that were here four hundred million years ago. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 55080,
#   'end_time': 62000,
#   'text': "The following is a conversation with Michael Levin, one of the most fascinating and brilliant biologists I've ever talked to. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 62620,
#   'end_time': 70980,
#   'text': 'He and his lab at Tufts University works on novel ways to understand and control complex pattern formation in biological systems. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 71680,
#   'end_time': 77840,
#   'text': "Andrej Karpathy, a world-class AI researcher, is the person who first introduced me to Michael Levin's work. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 78760,
#   'end_time': 89140,
#   'text': 'I bring this up because these two people make me realize that biology has a lot to teach us about AI, and AI might have a lot to teach us about biology. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 90320,
#   'end_time': 91960,
#   'text': 'This is the Lex Friedman podcast. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 92200,
#   'end_time': 95240,
#   'text': 'To support it, please check out our sponsors in the description. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 95820,
#   'end_time': 99080,
#   'text': "And now, dear friends, here's Michael Levin. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 100320,
#   'end_time': 104400,
#   'text': 'Embryogenesis is the process of building the human body from a single cell. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 104580,
#   'end_time': 109560,
#   'text': "I think it's one of the most incredible things that exists on earth from a single embryo. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 109760,
#   'end_time': 111180,
#   'text': 'So how does this process work? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 111680,
#   'end_time': 113500,
#   'text': 'Yeah, it is an incredible process. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 113940,
#   'end_time': 117080,
#   'text': "I think it's maybe the most magical process there is. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 117160,
#   'end_time': 126860,
#   'text': 'And I think one of the most fundamentally interesting things about it is that it shows that each of us takes the journey from so-called just physics to mind, right? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 126900,
#   'end_time': 131120,
#   'text': 'Because we all start life as a single quiescent, unfertilized oocyte. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 131520,
#   'end_time': 133000,
#   'text': "And it's basically a bag of chemicals. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 133060,
#   'end_time': 135200,
#   'text': 'And you look at that and you say, OK, this is chemistry and physics. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 135700,
#   'end_time': 142820,
#   'text': 'And then nine months and some years later, you have an organism with high level cognition and preferences and an inner life and so on. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 143520,
#   'end_time': 148020,
#   'text': 'And what embryogenesis tells us is that that transformation from physics to mind is gradual. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 148380,
#   'end_time': 148820,
#   'text': "It's smooth. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 149180,
#   'end_time': 155320,
#   'text': "There is no special place where, you know, a lightning bolt says, boom, now you've gone from from physics to true cognition. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 155360,
#   'end_time': 156000,
#   'text': "That doesn't happen. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 156400,
#   'end_time': 162720,
#   'text': 'And so we can see in this process that the whole mystery, you know, the biggest mystery of the of the universe, basically, how you get mind from matter. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 163480,
#   'end_time': 165480,
#   'text': 'from just physics in quotes. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 166300,
#   'end_time': 168020,
#   'text': "So where's the magic into the thing? "},
#  {'speaker': 'Speaker 1',
#   'start_time': 168780,
#   'end_time': 175140,
#   'text': 'How do we get from information encoded in DNA and make physical reality out of that information? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 175700,
#   'end_time': 184940,
#   'text': "So one of the things that I think is really important if we're going to bring in DNA into this picture is to think about the fact that what DNA encodes is the hardware of life. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 185300,
#   'end_time': 189840,
#   'text': 'DNA contains the instructions for the kind of micro level hardware that every cell gets to play with. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 189900,
#   'end_time': 196040,
#   'text': "So all the proteins, all the signaling factors, the ion channels, all the cool little pieces of hardware that cells have, that's what's in the DNA. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 196860,
#   'end_time': 209440,
#   'text': 'The rest of it is in so-called generic laws, and these are laws of mathematics, these are laws of computation, these are laws of physics, of all kinds of interesting things that are not directly in the DNA. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 210100,
#   'end_time': 217820,
#   'text': "And that process, you know, I think the reason I always put just physics in quotes is because I don't think there is such a thing as just physics. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 217940,
#   'end_time': 225440,
#   'text': "I think that thinking about these things in binary categories, like this is physics, this is true cognition, this is as if, it's only faking, these kinds of things. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 225820,
#   'end_time': 226880,
#   'text': "I think that's what gets us in trouble. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 227160,
#   'end_time': 233680,
#   'text': "I think that we really have to understand that it's a continuum and we have to work up the scaling, the laws of scaling, and we can certainly talk about that. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 233720,
#   'end_time': 236280,
#   'text': "There's a lot of really interesting thoughts to be had there. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 236740,
#   'end_time': 241440,
#   'text': 'So the physics is deeply integrated with the information. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 241520,
#   'end_time': 243200,
#   'text': "So the DNA doesn't exist on its own. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 243280,
#   'end_time': 250480,
#   'text': 'The DNA is integrated in some sense in response to the laws of physics at every scale. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 250520,
#   'end_time': 253580,
#   'text': 'The laws of the environment it exists in. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 254260,
#   'end_time': 256440,
#   'text': 'Yeah, the environment and also the laws of the universe. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 256519,
#   'end_time': 283660,
#   'text': "I mean, the thing about the thing about the DNA is that it's once evolution discovers a certain kind of machine, that if the physical implementation is appropriate, it's sort of, and this is hard to talk about, because we don't have a good vocabulary for this yet, but it's a very kind of a platonic notion that if the machine is there, it pulls down interesting things that you do not have to evolve from scratch because the laws of physics give it to you for free. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 283980,
#   'end_time': 291460,
#   'text': "So just as a really stupid example, if you're trying to evolve a particular triangle, you can evolve the first angle and you evolve the second angle, but you don't need to evolve the third. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 291640,
#   'end_time': 292520,
#   'text': 'You know what it is already. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 292820,
#   'end_time': 293460,
#   'text': 'Now, why do you know? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 293780,
#   'end_time': 296080,
#   'text': "That's a gift for free from geometry in a particular space. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 296120,
#   'end_time': 297120,
#   'text': 'You know what that angle has to be. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 297600,
#   'end_time': 301400,
#   'text': 'And if you evolve an ion channel, which is ion channels are basically transistors, right? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 301440,
#   'end_time': 303340,
#   'text': "They're voltage-gated current conductances. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 303780,
#   'end_time': 307540,
#   'text': 'If you evolve that ion channel, you immediately get to use things like truth tables. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 307580,
#   'end_time': 308540,
#   'text': 'You get logic functions. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 308840,
#   'end_time': 310220,
#   'text': "You don't have to evolve the logic function. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 310280,
#   'end_time': 311580,
#   'text': "You don't have to evolve a truth table. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 311620,
#   'end_time': 312520,
#   'text': "It doesn't have to be in the DNA. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 312980,
#   'end_time': 313940,
#   'text': "It's you get it for free. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 314340,
#   'end_time': 314500,
#   'text': 'Right. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 314580,
#   'end_time': 316900,
#   'text': 'And the fact that if you have NAND gates, you can build anything you want. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 316940,
#   'end_time': 317600,
#   'text': 'You get that for free. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 317960,
#   'end_time': 323760,
#   'text': 'All you have to evolve is that that first step, that first little machine that that enables you to couple to those laws. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 324120,
#   'end_time': 326420,
#   'text': "And there's laws of adhesion and many other things. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 326480,
#   'end_time': 344380,
#   'text': "And this is all that interplay between the hardware that's set up by the genetics and the physiological software that basically does all the computation and the cognition and everything else is the real interplay between the information and the DNA and the laws of physics of computation and so on. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 344760,
#   'end_time': 349420,
#   'text': 'So is it fair to say just like this idea that the laws of mathematics are discovered? '},
#  {'speaker': 'Speaker 1',
#   'start_time': 350780,
#   'end_time': 353240,
#   'text': "they're latent within the fabric of the universe. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 353340,
#   'end_time': 356140,
#   'text': 'in that same way the laws of biology are kind of discovered. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 356420,
#   'end_time': 360920,
#   'text': "Yeah, I think that's absolutely, and it's probably not a popular view, but I think that's right on the money, yeah. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 361180,
#   'end_time': 362940,
#   'text': "Well, I think that's a really deep idea. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 364140,
#   'end_time': 373880,
#   'text': 'Then embryogenesis is the process of revealing, of embodying, of manifesting these laws. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 374860,
#   'end_time': 380620,
#   'text': "You're not building the laws, you're just, creating the capacity to reveal. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 380900,
#   'end_time': 381040,
#   'text': 'Yes. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 381600,
#   'end_time': 386340,
#   'text': "I think, again, not the standard view of molecular biology by any means, but I think that's right on the money. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 386520,
#   'end_time': 387580,
#   'text': "I'll give you a simple example. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 387960,
#   'end_time': 389720,
#   'text': 'Some of our latest work with these xenobots, right? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 389780,
#   'end_time': 395540,
#   'text': "So what we've done is to take some skin cells off of an early frog embryo and basically ask about their plasticity. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 395600,
#   'end_time': 400060,
#   'text': 'If we give you a chance to sort of reboot your multicellularity in a different context, what would you do? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 400500,
#   'end_time': 402300,
#   'text': 'Because what you might assume. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 403080,
#   'end_time': 405360,
#   'text': "The thing about embryogenesis is that it's super reliable, right? "},
#  {'speaker': 'Speaker 0',
#   'start_time': 405420,
#   'end_time': 406300,
#   'text': "It's very robust. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 406700,
#   'end_time': 410440,
#   'text': 'And that really obscures some of its most interesting features. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 410500,
#   'end_time': 411120,
#   'text': 'We get used to it. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 411160,
#   'end_time': 414740,
#   'text': 'We get used to the fact that acorns make oak trees and frog eggs make frogs. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 414780,
#   'end_time': 415820,
#   'text': 'And we say, well, what else is it going to make? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 415860,
#   'end_time': 417020,
#   'text': "That's what it makes. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 417060,
#   'end_time': 417920,
#   'text': "That's a standard story. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 418760,
#   'end_time': 424460,
#   'text': 'But the reality is, and so you look at these skin cells, and you say, well, what do they know how to do? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 424560,
#   'end_time': 429920,
#   'text': 'Well, they know how to be a passive, boring, two-dimensional outer layer, keeping the bacteria from getting into the embryo. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 430000,
#   'end_time': 430680,
#   'text': "That's what they know how to do. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 431180,
#   'end_time': 439800,
#   'text': "Well, it turns out that if you take these skin cells and you remove the rest of the embryo, so you remove all of the rest of the cells and you say, well, you're by yourself. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 439880,
#   'end_time': 440480,
#   'text': 'now, what do you want to do? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 440920,
#   'end_time': 445860,
#   'text': 'So what they do is they form this little, this multi little creature that runs around the dish. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 445900,
#   'end_time': 447780,
#   'text': 'They have all kinds of incredible capacities. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 447840,
#   'end_time': 449240,
#   'text': 'They navigate through mazes. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 449320,
#   'end_time': 452600,
#   'text': 'They have various behaviors that they do both independently and together. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 455880,
#   'end_time': 468860,
#   'text': "Basically, they implement von Neumann's dream of self-replication, because if you sprinkle a bunch of loose cells into the dish, what they do is they run around, they collect those cells into little piles, they sort of mush them together until those little piles become the next generation of Xenobots. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 468900,
#   'end_time': 473200,
#   'text': "So you've got this machine that builds copies of itself from loose material in its environment. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 473580,
#   'end_time': 477960,
#   'text': 'None of this are things that you would have expected from the frog genome. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 478000,
#   'end_time': 479860,
#   'text': 'In fact, the genome is wild-type. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 479900,
#   'end_time': 481080,
#   'text': "There's nothing wrong with their genetics. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 481460,
#   'end_time': 484300,
#   'text': 'Nothing has been added, no nanomaterials, no genomic editing, nothing. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 484780,
#   'end_time': 488520,
#   'text': 'And so what we have done there is engineer by subtraction. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 489080,
#   'end_time': 494220,
#   'text': "What you've done is you've removed the other cells that normally basically bully these cells into being skin cells. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 494620,
#   'end_time': 498080,
#   'text': 'And you find out that what they really want to do is to be this. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 498480,
#   'end_time': 500700,
#   'text': 'They want their default behaviors to be a xenobot. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 501060,
#   'end_time': 505320,
#   'text': 'But in vivo, in the embryo, they get told to be skinned by these other cell types. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 505840,
#   'end_time': 510200,
#   'text': 'And so now here comes this really interesting question that you just posed. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 511340,
#   'end_time': 518179,
#   'text': "When you ask where does the form of the tadpole and the frog come from, the standard answer is, well, it's selection. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 518400,
#   'end_time': 524280,
#   'text': "So over millions of years, it's been shaped to produce the specific body that's fit for froggy environments. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 524940,
#   'end_time': 526480,
#   'text': 'Where does the shape of the xenobot come from? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 526840,
#   'end_time': 527960,
#   'text': "There's never been any xenobots. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 528000,
#   'end_time': 529740,
#   'text': "There's never been selection to be a good xenobot. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 530100,
#   'end_time': 531820,
#   'text': 'These cells find themselves in the new environment. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 532080,
#   'end_time': 539220,
#   'text': 'In forty-eight hours, they figure out how to be an entirely different a proto-organism with new capacities, like kinematic self-replication. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 539280,
#   'end_time': 540880,
#   'text': "That's not how frogs or tadpoles replicate. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 541220,
#   'end_time': 543540,
#   'text': "We've made it impossible for them to replicate their normal way. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 544000,
#   'end_time': 546000,
#   'text': 'Within a couple of days, these guys find a new way of doing it. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 546140,
#   'end_time': 547800,
#   'text': "that's not done anywhere else in the biosphere. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 548080,
#   'end_time': 551460,
#   'text': "Well, actually, let's step back and define what are xenobots? "},
#  {'speaker': 'Speaker 0',
#   'start_time': 552400,
#   'end_time': 555900,
#   'text': 'So a xenobot is a self-assembling little proto-organism. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 556420,
#   'end_time': 557800,
#   'text': "It's also a biological robot. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 558100,
#   'end_time': 559580,
#   'text': 'Those things are not distinct. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 559700,
#   'end_time': 560880,
#   'text': "It's a member of both classes. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 561740,
#   'end_time': 563160,
#   'text': 'How much is it biology? '},
#  {'speaker': 'Speaker 1',
#   'start_time': 563280,
#   'end_time': 564500,
#   'text': 'How much is it robot? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 565460,
#   'end_time': 574900,
#   'text': "At this point, most of it is biology because what we're doing is we're discovering natural behaviors of the cells and also of the cell collectives. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 575340,
#   'end_time': 581040,
#   'text': "Now, one of the really important parts of this was that we're working together with Josh Bongaert's group at University of Vermont. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 581120,
#   'end_time': 582360,
#   'text': "They're computer scientists. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 582780,
#   'end_time': 583520,
#   'text': 'They do AI. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 584080,
#   'end_time': 591940,
#   'text': "And they've basically been able to use a simulated evolution approach to ask, how can we manipulate these cells, give them signals? "},
#  {'speaker': 'Speaker 0',
#   'start_time': 592220,
#   'end_time': 595260,
#   'text': 'Not rewire their DNA, so not hardware, but experience signals. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 595640,
#   'end_time': 596780,
#   'text': 'So can we remove some cells? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 596840,
#   'end_time': 597720,
#   'text': 'Can we add some cells? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 597780,
#   'end_time': 600420,
#   'text': 'Can we poke them in different ways to get them to do other things? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 600820,
#   'end_time': 608500,
#   'text': "So in the future, there's going to be, we're now, and this is future unpublished work, but we're doing all sorts of interesting ways to reprogram them to new behaviors. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 608940,
#   'end_time': 613480,
#   'text': 'But before you can start to reprogram these things, you have to understand what their innate capacities are. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 613940,
#   'end_time': 619680,
#   'text': "Okay, so that means engineering programming, you're engineering them in the future. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 620080,
#   'end_time': 628960,
#   'text': 'And in some sense, the definition of a robot is something you in part engineer versus evolve. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 631140,
#   'end_time': 632940,
#   'text': "It's such a fuzzy definition. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 633020,
#   'end_time': 636980,
#   'text': 'anyway, in some sense, many of the organisms within our body are kinds of robots. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 638060,
#   'end_time': 643980,
#   'text': 'And I think robots is a weird line, because we tend to see robots as the other. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 644220,
#   'end_time': 652180,
#   'text': "I think there will be a time in the future when there's going to be something akin to the civil rights movements for robots, but we'll talk about that later perhaps. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 652680,
#   'end_time': 652940,
#   'text': 'Anyway. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 654900,
#   'end_time': 657640,
#   'text': 'So how do you, can we just linger on it? '},
#  {'speaker': 'Speaker 1',
#   'start_time': 657760,
#   'end_time': 659060,
#   'text': 'How do you build a Zenobot? '},
#  {'speaker': 'Speaker 1',
#   'start_time': 659460,
#   'end_time': 660620,
#   'text': 'What are we talking about here? '},
#  {'speaker': 'Speaker 1',
#   'start_time': 662880,
#   'end_time': 668840,
#   'text': 'From whence does it start and how does it become the glorious Zenobot? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 669100,
#   'end_time': 681420,
#   'text': 'Yeah, so just to take one step back, one of the things that a lot of people get stuck on is they say, well, engineering requires new DNA circuits, or it requires new nanomaterials. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 682380,
#   'end_time': 692700,
#   'text': 'The thing is, we are now moving from old school engineering, which used passive materials, things like wood, metal, things like this, that basically the only thing you could depend on is that they were going to keep their shape. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 692840,
#   'end_time': 693100,
#   'text': "That's it. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 693140,
#   'end_time': 693980,
#   'text': "They don't do anything else. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 694760,
#   'end_time': 697380,
#   'text': "It's on you as an engineer to make them do everything they're going to do. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 697480,
#   'end_time': 700360,
#   'text': 'And then there were active materials and now computation materials. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 700400,
#   'end_time': 701300,
#   'text': 'This is a whole new era. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 701380,
#   'end_time': 702760,
#   'text': 'These are agential materials. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 703160,
#   'end_time': 707000,
#   'text': "This is you're now collaborating with your substrate because your material has an agenda. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 707340,
#   'end_time': 712780,
#   'text': "These cells have billions of years of evolution, they have goals, they have preferences, they're not just going to sit where you put them. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 712840,
#   'end_time': 713600,
#   'text': "That's hilarious. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 714060,
#   'end_time': 716640,
#   'text': 'that you have to talk your material into keeping its shape. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 716980,
#   'end_time': 717880,
#   'text': 'That is exactly right. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 718300,
#   'end_time': 719380,
#   'text': 'That is exactly right. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 719520,
#   'end_time': 719940,
#   'text': 'Stay there. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 720380,
#   'end_time': 724840,
#   'text': "It's like getting a bunch of cats or something and trying to organize the shape out of them. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 725040,
#   'end_time': 730440,
#   'text': "It's funny, we're on the same page here, because in a paper, this is currently just been accepted in Nature Bioengineering. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 730840,
#   'end_time': 734420,
#   'text': 'One of the figures I have is building a tower out of Legos versus dogs. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 735120,
#   'end_time': 735900,
#   'text': 'So think about the difference. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 736100,
#   'end_time': 739780,
#   'text': "If you build out of Legos, you have full control over where it's going to go. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 740360,
#   'end_time': 742540,
#   'text': "But if somebody knocks it over, it's game over. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 742960,
#   'end_time': 745140,
#   'text': 'With the dogs, you cannot just come and stack them. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 745180,
#   'end_time': 746020,
#   'text': "They're not going to stay that way. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 746260,
#   'end_time': 749820,
#   'text': "But the good news is that if you train them, then somebody knocks it over, they'll get right back up. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 750220,
#   'end_time': 750940,
#   'text': "So it's all right. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 751000,
#   'end_time': 754500,
#   'text': 'So as an engineer, what you really want to know is what can I depend on this thing to do? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 754860,
#   'end_time': 755000,
#   'text': 'Right? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 755040,
#   'end_time': 761200,
#   'text': "That's really, you know, a lot of people have definitions of robots as far as what they're made over how they got here, you know, design versus evolve, whatever. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 761540,
#   'end_time': 762540,
#   'text': "I don't think any of that is useful. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 762680,
#   'end_time': 769280,
#   'text': "I think I think as an engineer, what you want to know is, how much can I depend on this thing to do when I'm not around to micromanage it? "},
#  {'speaker': 'Speaker 0',
#   'start_time': 769400,
#   'end_time': 773100,
#   'text': 'What level of what level of dependency can I give this thing? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 773140,
#   'end_time': 774240,
#   'text': 'How much agency does it have? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 774560,
#   'end_time': 776240,
#   'text': 'Which then tells you what techniques do you use? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 776280,
#   'end_time': 777440,
#   'text': 'So do you use micromanagement? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 777480,
#   'end_time': 778640,
#   'text': 'Like you put everything where it goes? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 778940,
#   'end_time': 779580,
#   'text': 'Do you train it? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 779940,
#   'end_time': 781020,
#   'text': 'Do you give it signals? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 781060,
#   'end_time': 782380,
#   'text': 'Do you try to convince it to do things? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 783180,
#   'end_time': 784400,
#   'text': 'How intelligent is your substrate? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 784720,
#   'end_time': 789460,
#   'text': "And so now we're moving into this area where you're working with agential materials. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 789720,
#   'end_time': 790580,
#   'text': "That's a collaboration. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 790640,
#   'end_time': 792740,
#   'text': "That's not old style engineering. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 792780,
#   'end_time': 794380,
#   'text': "What's the word you're using, agential? "},
#  {'speaker': 'Speaker 1',
#   'start_time': 794520,
#   'end_time': 795160,
#   'text': 'Agential, yeah. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 795200,
#   'end_time': 795640,
#   'text': "What's that mean? "},
#  {'speaker': 'Speaker 0',
#   'start_time': 795880,
#   'end_time': 797300,
#   'text': 'Agency, it comes from the word agency. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 797620,
#   'end_time': 810120,
#   'text': 'So basically the material has agency, meaning that, It has some level of, obviously not human level, but some level of preferences, goals, memories, ability to remember things, to compute into the future, meaning anticipate. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 811040,
#   'end_time': 814440,
#   'text': "When you're working with cells, they have all of that to various degrees. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 814960,
#   'end_time': 819760,
#   'text': 'Is that empowering or limiting, having material as a mind of its own, literally? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 820100,
#   'end_time': 820860,
#   'text': "I think it's both, right? "},
#  {'speaker': 'Speaker 0',
#   'start_time': 820920,
#   'end_time': 836420,
#   'text': "So it raises difficulties because it means that if you're using the old mindset, which is a linear kind of extrapolation of what's going to happen, you're going to be surprised and shocked all the time because biology does not do what we linearly expect materials to do. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 837000,
#   'end_time': 850320,
#   'text': "on the other hand it's massively liberating and so in the following way i've argued that advances in regenerative medicine require us to take advantage of this because what it means is that you can get the material to do things that you don't know how to micromanage. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 850640,
#   'end_time': 863260,
#   'text': 'so just as a simple example right if you if you had a rat And you wanted this rat to do a circus trick, put a ball in the little hoop, you can do it the micromanagement way, which is try to control every neuron and try to play the thing like a puppet, right? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 863320,
#   'end_time': 866300,
#   'text': "And maybe someday that'll be possible, maybe, or you can train the rat. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 866760,
#   'end_time': 872720,
#   'text': "And this is why humanity for thousands of years before we knew any neuroscience, we had no idea what's behind what's between the ears of any animal. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 873020,
#   'end_time': 880140,
#   'text': 'We were able to train these animals, because once you recognize the level of agency of a certain system, you can use appropriate techniques. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 880200,
#   'end_time': 891620,
#   'text': 'If you know the currency of motivation, reward and punishment, you know how smart it is, you know what kinds of things it likes to do, you are searching a much smoother, much nicer problem space than if you try to micromanage the thing. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 892020,
#   'end_time': 903720,
#   'text': "And in regenerative medicine, when you're trying to get, let's say, an arm to grow back or an eye to repair a cell birth defect or something, do you really want to be controlling tens of thousands of genes at each point to try to micromanage it? "},
#  {'speaker': 'Speaker 0',
#   'start_time': 904080,
#   'end_time': 908580,
#   'text': 'Or do you want to find the high-level modular controls that say, build an arm here? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 908740,
#   'end_time': 909740,
#   'text': 'You already know how to build an arm. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 909800,
#   'end_time': 910520,
#   'text': 'You did it before. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 910640,
#   'end_time': 911000,
#   'text': 'Do it again. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 911500,
#   'end_time': 913200,
#   'text': "So I think it's both. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 913260,
#   'end_time': 916400,
#   'text': "It's both difficult, and it challenges us to develop new ways of engineering. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 916840,
#   'end_time': 918560,
#   'text': "And it's hugely empowering. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 919340,
#   'end_time': 931820,
#   'text': 'Okay, so how do you do, I mean maybe sticking with the metaphor of dogs and cats, I presume you have to figure out, find the dogs and dispose of the cats. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 933920,
#   'end_time': 942260,
#   'text': "Because it's like the old herding cats is an issue, so you may be able to train dogs, I suspect you will not be able to train cats. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 943340,
#   'end_time': 945720,
#   'text': "or if you do, you're never gonna be able to trust them. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 946280,
#   'end_time': 952280,
#   'text': 'So is there a way to figure out which material is amenable to hurting? '},
#  {'speaker': 'Speaker 1',
#   'start_time': 952720,
#   'end_time': 955680,
#   'text': 'Is it in the lab work or is it in simulation? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 956200,
#   'end_time': 963880,
#   'text': "Right now it's largely in the lab because our simulations do not capture yet the most interesting and powerful things about biology. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 963960,
#   'end_time': 970420,
#   'text': "So the simulation does, what we're pretty good at simulating are feed forward emergent types of things. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 970900,
#   'end_time': 978660,
#   'text': 'So cellular automata, if you have simple rules and you roll those forward for every agent or every cell in the simulation, then complex things happen. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 978940,
#   'end_time': 980860,
#   'text': 'Ant colony or algorithms, things like that. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 981580,
#   'end_time': 982900,
#   'text': "We're good at that, and that's fine. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 982940,
#   'end_time': 986720,
#   'text': "The difficulty with all of that is that it's incredibly hard to reverse. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 987020,
#   'end_time': 988480,
#   'text': 'So this is a really hard inverse problem. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 988720,
#   'end_time': 993700,
#   'text': "If you look at a bunch of termites and they make a thing with a single chimney and you say, well, I like it, but I'd like two chimneys. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 994640,
#   'end_time': 997640,
#   'text': 'How do you change the rules of behavior-free termites so they make two chimneys? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 998140,
#   'end_time': 1003300,
#   'text': "Or if you say, here are a bunch of cells that are creating this kind of organism, I don't think that's optimal. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1003400,
#   'end_time': 1005080,
#   'text': "I'd like to repair that birth defect. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1005500,
#   'end_time': 1010140,
#   'text': 'How do you control all the individual low-level rules, all the protein interactions and everything else? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1010520,
#   'end_time': 1015740,
#   'text': 'Rolling it back from the anatomy that you want to the low-level hardware rules is, in general, intractable. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1016080,
#   'end_time': 1017800,
#   'text': "It's an inverse problem that's generally not solvable. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1018580,
#   'end_time': 1024819,
#   'text': "So right now it's mostly in the lab, because what we need to do is we need to understand how biology uses top-down controls. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1025240,
#   'end_time': 1037240,
#   'text': "So the idea is not bottom-up emergence, but the idea of things like goal-directed test-operate exit kinds of loops, where it's basically an error minimization function over a new space. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1037300,
#   'end_time': 1040020,
#   'text': "It's not a space of gene expression, but for example, a space of anatomy. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1040579,
#   'end_time': 1047579,
#   'text': "So just as a simple example, if you have a salamander and it's got an arm, you can amputate that arm anywhere along the length. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1048000,
#   'end_time': 1050420,
#   'text': "It will grow exactly what's needed, and then it stops. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1050500,
#   'end_time': 1052960,
#   'text': "That's the most amazing thing about regeneration is that it stops. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1053000,
#   'end_time': 1053780,
#   'text': 'It knows when to stop. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1054120,
#   'end_time': 1054680,
#   'text': 'When does it stop? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1054740,
#   'end_time': 1057140,
#   'text': 'It stops when a correct salamander arm has been completed. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1057520,
#   'end_time': 1065140,
#   'text': "So that tells you that's a a means ends kind of analysis where it has to know what the correct limb is supposed to look like. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1065260,
#   'end_time': 1065400,
#   'text': 'right. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1065460,
#   'end_time': 1067860,
#   'text': 'so it has a way to ascertain the current shape. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1067920,
#   'end_time': 1075480,
#   'text': "it has a way to measure that delta from from what shape it's supposed to be and it will keep taking actions meaning remodeling and growing and everything else until that's complete. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1075860,
#   'end_time': 1086840,
#   'text': "So once you know that, and we've taken advantage of this in the lab to do some really wild things with both planaria and frog embryos and so on, once you know that, you can start playing with that homeostatic cycle. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1087160,
#   'end_time': 1089840,
#   'text': 'You can ask, for example, well, how does it remember what the correct shape is? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1089900,
#   'end_time': 1090880,
#   'text': 'And can we mess with that memory? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1091160,
#   'end_time': 1094680,
#   'text': 'Can we give it a false memory of what the shape should be and let the cells build something else? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1095060,
#   'end_time': 1096680,
#   'text': 'Or can we mess with the measurement apparatus? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1097080,
#   'end_time': 1099860,
#   'text': 'So it gives you those kinds of things. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1099900,
#   'end_time': 1112840,
#   'text': 'So the idea is to basically appropriate a lot of the approaches and concepts from cognitive neuroscience and behavioral science into things that previously were taken to be dumb materials. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1113240,
#   'end_time': 1118980,
#   'text': 'And you get yelled at in class for being anthropomorphic if you said, well, my cells want to do this and my cells want to do that. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1119400,
#   'end_time': 1121360,
#   'text': "And I think that's a major mistake. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1121400,
#   'end_time': 1123300,
#   'text': 'that leaves a ton of capabilities on the table. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 1123580,
#   'end_time': 1142160,
#   'text': 'So thinking about biological systems as things that have memory, have almost something like cognitive ability, I mean, how incredible is it, you know, that the salamander arm is being rebuilt, not with a dictator. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 1143260,
#   'end_time': 1145040,
#   'text': "It's kind of like the cellular automata system. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 1145280,
#   'end_time': 1147380,
#   'text': 'All the individual workers are doing their own thing. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 1148100,
#   'end_time': 1152920,
#   'text': "So where's that top-down signal that does the control coming from? "},
#  {'speaker': 'Speaker 1',
#   'start_time': 1153040,
#   'end_time': 1154660,
#   'text': 'Like, how can you find it? '},
#  {'speaker': 'Speaker 1',
#   'start_time': 1155300,
#   'end_time': 1156560,
#   'text': 'Like, why does it stop growing? '},
#  {'speaker': 'Speaker 1',
#   'start_time': 1156920,
#   'end_time': 1158180,
#   'text': 'How does it know the shape? '},
#  {'speaker': 'Speaker 1',
#   'start_time': 1158600,
#   'end_time': 1159960,
#   'text': 'How does it have memory of the shape? '},
#  {'speaker': 'Speaker 1',
#   'start_time': 1160440,
#   'end_time': 1163880,
#   'text': "And how does it tell everybody to be like, whoa, whoa, slow down, we're done. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1164340,
#   'end_time': 1176400,
#   'text': 'So the first thing to think about, I think, is that there are no examples anywhere of a central dictator in this kind of science because everything is made of parts. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1176600,
#   'end_time': 1185060,
#   'text': 'And so we, even though we feel as a unified central intelligence and point of cognition, we are a bag of neurons. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1186020,
#   'end_time': 1187620,
#   'text': 'All intelligence is collective intelligence. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1188620,
#   'end_time': 1191140,
#   'text': 'This is important to kind of about. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1191180,
#   'end_time': 1199880,
#   'text': "Because a lot of people think, okay, there's real intelligence, like me, and then there's collective intelligence, which is ants and flocks of birds and termites and things like that. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1201520,
#   'end_time': 1207740,
#   'text': "And maybe it's appropriate to think of them as an individual, and maybe it's not, and a lot of people are skeptical about that and so on. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1208100,
#   'end_time': 1215880,
#   'text': "But you've got to realize that there's no such thing as this indivisible diamond of intelligence that's like this one central thing that's not made of parts. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1215940,
#   'end_time': 1216780,
#   'text': 'We are all made of parts. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1217280,
#   'end_time': 1233460,
#   'text': 'And so if you believe, which I think is hard to get around, that we in fact have a centralized set of goals and preferences and we plan and we do things and so on, you are already committed to the fact that a collection of cells is able to do this because we are a collection of cells. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 1233600,
#   'end_time': 1234400,
#   'text': "There's no getting around that. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 1234900,
#   'end_time': 1238560,
#   'text': 'In our case, what we do is we navigate the three-dimensional world and we have behavior. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 1238740,
#   'end_time': 1241920,
#   'text': 'This is blowing my mind right now because we are just a collection of cells. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 1241960,
#   'end_time': 1242540,
#   'text': 'Oh yeah, yeah. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 1242940,
#   'end_time': 1250200,
# ...
#  {'speaker': 'Speaker 0',
#   'start_time': 4113939,
#   'end_time': 4117439,
#   'text': "They know exactly, every piece knows exactly what's missing, what needs to happen. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4118600,
#   'end_time': 4127760,
#   'text': "In fact, if you chop it in half, as it grows the other half, the original tissue shrinks so that when the new tiny head shows up, they're proportional. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4128200,
#   'end_time': 4129920,
#   'text': 'So it keeps perfect proportion. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4130279,
#   'end_time': 4131800,
#   'text': 'If you starve them, they shrink. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4131880,
#   'end_time': 4133240,
#   'text': 'If you feed them again, they expand. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4133819,
#   'end_time': 4136600,
#   'text': 'Their control, their anatomical control is just insane. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 4136700,
#   'end_time': 4138939,
#   'text': 'Somebody cut them into over two hundred pieces. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4139120,
#   'end_time': 4140580,
#   'text': 'Yeah, Thomas Hunt Morgan did. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4140800,
#   'end_time': 4141899,
#   'text': 'Hashtag science. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4142300,
#   'end_time': 4142620,
#   'text': 'Amazing. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4142740,
#   'end_time': 4142800,
#   'text': 'Yeah. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4142899,
#   'end_time': 4143420,
#   'text': 'And maybe more. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4143500,
#   'end_time': 4144840,
#   'text': "I mean, they didn't have antibiotics back then. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4144899,
#   'end_time': 4146160,
#   'text': 'I bet he lost some due to infection. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4146540,
#   'end_time': 4147620,
#   'text': "I bet it's actually more than that. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4147979,
#   'end_time': 4148880,
#   'text': 'I bet you could do more than that. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 4149060,
#   'end_time': 4150040,
#   'text': "Humans can't do that. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4151920,
#   'end_time': 4152600,
#   'text': 'Well, yes. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4152660,
#   'end_time': 4157060,
#   'text': 'I mean, again, true, except that- Maybe you can at the embryonic level. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4157100,
#   'end_time': 4158260,
#   'text': "Well, that's the thing, right? "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4158479,
#   'end_time': 4167660,
#   'text': 'So when I talk about this, I say, just remember that as amazing as it is to grow a whole planarian from a tiny fragment, half of the human population can grow a full body from one cell. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4168220,
#   'end_time': 4168380,
#   'text': 'Right? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4168700,
#   'end_time': 4174240,
#   'text': 'So, so development is really, you can look at development as a, as a, just an example of regeneration. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 4175020,
#   'end_time': 4175160,
#   'text': 'Yeah. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 4175300,
#   'end_time': 4185600,
#   'text': "To think we'll talk about regenerative medicine, but there's some sense of what would be like that warm in like five hundred years where I can just go regrow a hand. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4186439,
#   'end_time': 4186600,
#   'text': 'Yep. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4186899,
#   'end_time': 4191260,
#   'text': 'I, with given time, it takes time to grow large things, but yeah, I think so. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 4191800,
#   'end_time': 4193979,
#   'text': 'I think you can probably, why not accelerate? '},
#  {'speaker': 'Speaker 1',
#   'start_time': 4194460,
#   'end_time': 4196300,
#   'text': 'Oh, biology takes its time. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4197020,
#   'end_time': 4200540,
#   'text': "I'm not going to say anything is impossible, but I don't know of a way to accelerate these processes. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4200580,
#   'end_time': 4201360,
#   'text': "I think it's possible. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4201440,
#   'end_time': 4204920,
#   'text': "I think we are going to be regenerative, but I don't know of a way to make it fast. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 4205040,
#   'end_time': 4210620,
#   'text': 'I could just think people from a few centuries from now would be like, well, they used to have the way. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 4211860,
#   'end_time': 4213640,
#   'text': 'a week for the hand to regrow. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 4214300,
#   'end_time': 4216120,
#   'text': "It's like when the microwave was invented. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 4217300,
#   'end_time': 4221700,
#   'text': "You can toast your, what's that called when you put a cheese on a toast? "},
#  {'speaker': 'Speaker 1',
#   'start_time': 4225480,
#   'end_time': 4226680,
#   'text': "It's delicious is all I know. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 4226960,
#   'end_time': 4227940,
#   'text': "I'm blanking. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 4228400,
#   'end_time': 4230560,
#   'text': 'All right, so planaria. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 4231200,
#   'end_time': 4234360,
#   'text': 'Why were we talking about the magical planaria that they have the mystery of life? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4234460,
#   'end_time': 4237540,
#   'text': "Yeah, so the reason we're talking about planaria is not only are they immortal, okay? "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4237880,
#   'end_time': 4243420,
#   'text': "Not only do they regenerate every part of the body, they generally don't get cancer, right? "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4243880,
#   'end_time': 4244880,
#   'text': 'So which we can talk about? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4244940,
#   'end_time': 4245660,
#   'text': "why that's important. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4246080,
#   'end_time': 4247760,
#   'text': "They're smart, they can learn things, so you can train them. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4248320,
#   'end_time': 4255760,
#   'text': 'And it turns out that if you train a plein air and then cut their heads off, the tail will regenerate a brand new brain that still remembers the original information. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 4256180,
#   'end_time': 4258720,
#   'text': 'Do they have a biological network going on or no? '},
#  {'speaker': 'Speaker 1',
#   'start_time': 4259120,
#   'end_time': 4259240,
#   'text': 'Yes. '},
#  {'speaker': 'Speaker 1',
#   'start_time': 4259440,
#   'end_time': 4264500,
#   'text': "So their somatic cells are forming a network and that's what you mean by a true brain? "},
#  {'speaker': 'Speaker 1',
#   'start_time': 4264840,
#   'end_time': 4266600,
#   'text': "What's the requirement for a true brain? "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4267260,
#   'end_time': 4268000,
#   'text': 'I like everything else. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4268040,
#   'end_time': 4276300,
#   'text': "It's a continuum, but, but, but a true brain has certain characteristics as far as the density, like a localized density of neurons that guides behavior in the head. "},
#  {'speaker': 'Speaker 1',
#   'start_time': 4276720,
#   'end_time': 4277340,
#   'text': 'Exactly. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4277640,
#   'end_time': 4277960,
#   'text': 'Exactly. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4278000,
#   'end_time': 4281440,
#   'text': "If you cut their head off, uh, the, the tail doesn't have, that doesn't do anything. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4281480,
#   'end_time': 4291060,
#   'text': "It just sits there until the new brain is, is, is, you know, until a new brain regenerates, they have all the same neurotransmitters that you and I have, but here's why, here's what we're talking about them in this, in this context. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4291580,
#   'end_time': 4292320,
#   'text': "So here's your plenary. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4292400,
#   'end_time': 4294340,
#   'text': 'You cut off the head, you cut off the tail, you have a middle fragment. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4294700,
#   'end_time': 4296560,
#   'text': 'That middle fragment has to make one head and one tail. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4297040,
#   'end_time': 4299720,
#   'text': 'How does it know how many of each to make and where do they go? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4299840,
#   'end_time': 4300720,
#   'text': "How come it doesn't switch? "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4300760,
#   'end_time': 4301020,
#   'text': 'How come? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4303100,
#   'end_time': 4315480,
#   'text': "We did a very simple thing and we said, okay, let's make the hypothesis that there's a somatic electrical network that remembers the correct pattern and that what it's doing is recalling that memory and building to that pattern. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4316080,
#   'end_time': 4320780,
#   'text': 'What we did was we used a way to visualize electrical activity in these cells. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4321760,
#   'end_time': 4324400,
#   'text': "It's a variant of what people used to look for electricity in the brain. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4324980,
#   'end_time': 4330120,
#   'text': 'and we saw that it has a that that fragment has a very very particular electrical pattern. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4330160,
#   'end_time': 4330900,
#   'text': 'you can literally see it. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4331280,
#   'end_time': 4337700,
#   'text': 'once once we develop the technique it has a very particular electrical pattern that shows you where the head and the tail goes. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4338100,
#   'end_time': 4339080,
#   'text': 'right you can you can just see it. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4339540,
#   'end_time': 4344580,
#   'text': "and then we said okay well now let's test the idea that that's a memory that actually controls where the head and the tail goes. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4344900,
#   'end_time': 4345840,
#   'text': "let's change that pattern. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4345900,
#   'end_time': 4347520,
#   'text': 'so basically incept the false memory. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4347980,
#   'end_time': 4350020,
#   'text': 'And so what you can do is you can do that in many different ways. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4350140,
#   'end_time': 4352520,
#   'text': 'One way is with drugs that target ion channels. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4353420,
#   'end_time': 4361460,
#   'text': "And so you pick these drugs, and you say, OK, I'm going to do it so that instead of this one head, one tail electrical pattern, you have a two-headed pattern. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4361500,
#   'end_time': 4364240,
#   'text': "You're just editing the electrical information in the network. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4364760,
#   'end_time': 4366060,
#   'text': 'When you do that, guess what the cells build? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4366220,
#   'end_time': 4367140,
#   'text': 'They build a two-headed worm. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4367220,
#   'end_time': 4370280,
#   'text': 'And the coolest thing about it, now, no genetic changes. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4370380,
#   'end_time': 4371140,
#   'text': "We haven't touched the genome. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4371180,
#   'end_time': 4372160,
#   'text': 'The genome is totally wild type. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4372200,
#   'end_time': 4380580,
#   'text': 'But the amazing thing about it is that when you take these two-headed animals and you cut them into pieces again, some of those pieces will continue to make two-headed animals. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4382280,
#   'end_time': 4392020,
#   'text': 'So that information, that memory, that electrical circuit, not only does it hold the information for how many heads, not only does it use that information to tell the cells what to do to regenerate, but it stores it. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4392220,
#   'end_time': 4393260,
#   'text': "Once you've reset it, it keeps. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4393760,
#   'end_time': 4394400,
#   'text': 'And we can go back. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4394460,
#   'end_time': 4397260,
#   'text': 'We can take a two-headed animal and put it back to one-headed. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4398580,
#   'end_time': 4403320,
#   'text': "So there's a couple of interesting things here that have implications for understanding genomes and things like that. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4404040,
#   'end_time': 4405460,
#   'text': 'Imagine I take this two-headed animal. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4405760,
#   'end_time': 4410520,
#   'text': 'Oh, and by the way, when they reproduce, when they tear themselves in half, you still get two-headed animals. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4410840,
#   'end_time': 4412900,
#   'text': 'So imagine I take them and I throw them in the Charles River over here. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4413240,
#   'end_time': 4418900,
#   'text': "So a hundred years later, some scientists come along and they scoop up some samples and they go, oh, there's a single-headed form and a two-headed form. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4419160,
#   'end_time': 4420340,
#   'text': 'Wow, a speciation event. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4420440,
#   'end_time': 4420660,
#   'text': 'Cool. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4420700,
#   'end_time': 4423160,
#   'text': "let's sequence the genome and see why what happened? "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4423360,
#   'end_time': 4424160,
#   'text': 'the genomes are identical. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4424200,
#   'end_time': 4425160,
#   'text': "there's nothing wrong with the genome. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4425560,
#   'end_time': 4427300,
#   'text': 'so if you ask the question how does so? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4427420,
#   'end_time': 4430080,
#   'text': 'so this goes back to your very first question is where do body plans come from? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4430180,
#   'end_time': 4433300,
#   'text': "right how does the planarian know how many heads it's supposed to have? "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4433820,
#   'end_time': 4436280,
#   'text': "now it's interesting because you could say dna. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4437140,
#   'end_time': 4437740,
#   'text': 'but what happened? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4437800,
#   'end_time': 4437920,
#   'text': 'what? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4438020,
#   'end_time': 4438160,
#   'text': 'what? '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4438360,
#   'end_time': 4448240,
#   'text': "as it turns out the dna produces a piece of hardware that by default says one head the way that when you turn on a calculator by default it's a zero every single time. "},
#  {'speaker': 'Speaker 0',
#   'start_time': 4448280,
#   'end_time': 4449340,
#   'text': 'right when you turn it on just says zero. '},
#  {'speaker': 'Speaker 0',
#   'start_time': 4449800,
#   'end_time': 4451800,
#   'text': "but it's a programmable calculator as it turns out. "},
#  ...]

# %% [markdown]
# ## Cleanup and Exporing the results

# %%
with open(f"{os.path.splitext(audio_path)[0]}.txt", "w", encoding="utf-8-sig") as f:
    get_speaker_aware_transcript(ssm, f)

with open(f"{os.path.splitext(audio_path)[0]}.srt", "w", encoding="utf-8-sig") as srt:
    write_srt(ssm, srt)

cleanup(temp_path)
